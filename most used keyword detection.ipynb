# %%
from transformers import AutoTokenizer, AutoModel
import torch
import pandas as pd
import numpy as np
import re
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import warnings
from wordcloud import WordCloud, STOPWORDS

warnings.filterwarnings("ignore")

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min = 1e-9)


def embeding_calc(sentences):

    # tokenizing
    encoded_input = tokenizer(sentences, padding = True, truncation = True, return_tensors = 'pt')

    # passing though model
    with torch.no_grad():
        model_output = model(**encoded_input)

    sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

    return sentence_embeddings

# %%
result = embeding_calc(['balanced sound','good sound'])
result
# Out:
# tensor([[ 1.3816e-01, -2.8183e-01,  4.8961e-02, -5.4833e-01, -4.4829e-01,
#          -9.4074e-02,  1.8008e-02, -2.3150e-01, -1.0735e-01, -1.7051e-01,
#           8.0055e-02,  1.6925e-01,  3.1769e-01, -1.9897e-01,  7.5435e-02,
#           2.0244e-01,  4.0411e-01,  3.6702e-01, -2.6712e-01,  2.2276e-01,
#          -8.3083e-02,  1.1955e-01, -2.5500e-01,  1.7094e-01, -2.5472e-01,
#           3.7326e-01, -4.4425e-01, -1.0340e-01,  1.6339e-01, -1.6743e-01,
#           2.5092e-01,  1.5527e-02,  4.6127e-01, -4.6026e-01, -4.9595e-01,
#          -2.3598e-01,  2.2898e-01, -1.0325e-01, -5.1157e-01,  2.9932e-01,
#          -5.6495e-02,  2.5054e-01,  3.5081e-02, -2.2856e-01, -1.1837e-01,
#          -5.3377e-02, -4.1719e-01,  1.4727e-01, -2.5829e-02,  1.5994e-01,
#          -3.5641e-01,  1.6821e-01,  5.6168e-02,  1.6326e-01, -4.2926e-01,
#           3.2207e-02,  2.7500e-01,  6.7067e-01, -2.5572e-01,  5.8163e-02,
#           7.0676e-02, -2.5975e-01, -2.1105e-01,  2.2047e-01, -9.3347e-02,
#           6.2570e-01,  1.9075e-01,  8.1382e-02, -1.2507e-01,  3.3488e-01,
#          -1.1165e-01,  2.4437e-01,  5.4325e-02, -5.3291e-01,  2.3150e-01,
#          -1.5743e-01, -5.5516e-03, -3.7009e-01,  1.1698e-01,  1.0292e-01,
#           2.4730e-02, -2.1106e-01, -1.5926e-01, -5.0020e-01,  3.1573e-01,
#          -1.9829e-01, -3.9769e-01,  8.5513e-02, -4.3107e-01, -2.7264e-01,
#          -4.8286e-01,  2.2795e-01, -4.4054e-02,  3.4887e-01,  6.1092e-01,
#           4.2819e-01,  2.6493e-01,  2.3541e-01,  3.4902e-01,  1.1902e+00,
#           1.5725e-01, -6.4450e-02,  1.5846e-01,  2.4089e-01, -3.8276e-01,
#          -2.3178e-01, -1.7605e-01,  1.7743e-01, -1.7838e-01,  9.2674e-02,
#           6.0267e-02, -8.8219e-02, -2.2659e-01,  3.9554e-01,  3.6350e-01,
#          -2.5989e-01, -2.3980e-01,  4.9100e-01, -1.9760e-01,  1.5592e-01,
#          -1.4722e-01, -3.7399e-01, -2.0410e-01, -1.5229e-01,  5.4209e-01,
#          -3.4717e-01,  2.3111e-01, -1.9386e-01,  4.7962e-02, -1.7091e-01,
#           2.8996e-01, -1.5100e-01,  1.3388e-01, -2.3828e-02, -3.7733e-01,
#           9.0735e-02,  4.7947e-01,  4.5729e-01,  5.1778e-01,  3.2577e-01,
#          -3.0855e-01, -9.4136e-02, -2.4970e-01, -6.4177e-01, -1.9964e-01,
#           3.3857e-01, -8.1685e-01, -6.8996e-02,  7.6521e-02, -1.0457e-01,
#           1.7382e-01, -3.0691e-01,  2.0086e-01, -1.3987e-01,  1.9797e-02,
#           2.8404e-01, -6.2457e-03, -7.1687e-02, -3.5243e-01,  5.6159e-02,
#          -2.9533e-01, -2.8025e-01, -2.3622e-01, -1.5535e-01, -3.1705e-01,
#           4.5178e-01, -1.8049e-01, -5.1338e-03, -1.4867e-01, -2.3761e-01,
#          -7.0762e-02, -1.0763e-01,  2.7867e-01, -4.9469e-01, -1.4413e-02,
#           2.3812e-02, -3.5330e-01,  1.9710e-01,  1.1458e-02, -1.3721e-01,
#          -8.7762e-02,  3.7654e-01,  2.7463e-01, -5.2841e-02,  3.6241e-01,
#           1.6613e-01, -1.7556e-01,  9.4475e-02,  1.2001e-01,  7.0335e-02,
#           1.9763e-01, -3.3049e-01,  1.0648e-01,  2.6703e-01, -3.4025e-01,
#          -7.2266e-01,  1.6683e-01, -7.8727e-04,  1.6659e-01, -2.0492e-02,
#          -3.5323e-01,  3.8010e-01, -7.3897e-02,  4.2100e-01,  1.3857e-01,
#           6.7856e-02,  3.8439e-02,  2.6092e-01, -2.7002e-01,  4.9735e-01,
#          -2.0376e-01, -2.8659e-01,  2.3221e-01, -1.9749e-01, -3.4922e-02,
#          -6.5890e-01, -2.6807e-03, -7.4961e-02, -4.5613e-01,  2.0796e-01,
#          -1.8516e-01, -4.7425e-01,  5.5948e-01, -5.6707e-01,  1.3172e-01,
#           1.5292e-01, -3.6764e-02,  3.5359e-01, -2.6430e-01,  3.6281e-01,
#           1.8555e-01, -2.7278e-02, -4.7003e-02, -6.5701e-02,  5.9473e-01,
#          -4.7004e-01, -2.3443e-01,  3.1696e-01, -4.4800e-01, -5.3278e-01,
#           3.4506e-01, -1.0837e-01,  7.4644e-01,  1.3391e-01,  2.1956e-01,
#          -3.2449e-01,  3.5944e-01,  6.7406e-01, -5.3191e-01,  3.8351e-01,
#          -4.9162e-01, -2.2814e-01,  3.3732e-01, -6.0402e-02,  1.6918e-01,
#          -3.8087e-01,  3.1795e-01, -9.2880e-02,  1.3644e-01,  1.1995e-01,
#           8.4336e-02,  4.6906e-01,  2.8397e-01, -2.9076e-02,  1.3074e-01,
#           2.2191e-01,  7.9138e-02,  6.9337e-02, -4.9850e-02, -1.0619e-01,
#          -8.9707e-02, -4.7351e-02, -7.5435e-01, -4.4008e-01,  1.7663e-01,
#          -1.0998e-01,  4.2123e-02, -3.1204e-01, -7.2680e-02,  2.9604e-01,
#          -2.4168e-01, -3.7855e-01,  1.9846e-01,  2.9363e-01,  2.9278e-01,
#          -1.2084e-01, -1.7519e-01, -3.1268e-01,  1.7074e-01,  6.0290e-01,
#           2.6874e-01,  1.1407e-01,  1.9828e-01,  1.8906e-01, -1.1315e-01,
#           1.8119e-01,  3.4553e-01,  3.1396e-02, -1.0631e-01,  3.1534e-02,
#          -1.7188e-01, -2.4161e-01, -7.0497e-02,  2.4538e-01, -3.6427e-01,
#           8.0525e-03, -2.6852e-01, -3.4699e-01, -3.0191e-01,  5.3200e-01,
#          -3.3666e-01, -6.7120e-02, -4.8022e-02,  1.9166e-01,  3.5806e-01,
#           6.1680e-01,  3.7887e-01,  9.0042e-02,  2.7960e-01, -6.2173e-01,
#          -1.5989e-01, -2.5543e-01, -1.9450e-01, -5.0073e-01, -1.9001e-01,
#          -3.5340e-01,  1.1366e-01, -1.1446e+00, -2.2216e-01, -3.8486e-02,
#           1.3072e-01, -2.7481e-01, -1.4816e-01, -4.5016e-02,  2.4086e-01,
#           5.7483e-01, -3.9743e-01,  4.1004e-01, -3.3057e-01,  8.2910e-06,
#           6.2364e-01,  2.7559e-01,  1.6166e-01, -1.1680e-01, -3.3359e-01,
#           7.6772e-02,  1.6016e-01, -2.0635e-01, -2.3929e-01, -5.9697e-01,
#           8.0541e-02,  3.2329e-01, -4.2647e-01, -4.1330e-01,  1.7359e-01,
#          -2.3697e-01, -3.5219e-02,  2.0258e-01, -2.1289e-01,  6.9259e-01,
#           4.6030e-01,  2.9261e-01, -4.6450e-01,  2.5092e-01,  3.0188e-01,
#          -8.5378e-02,  1.2371e-01,  9.8459e-02,  1.1828e-01,  1.9872e-01,
#          -2.1642e-01,  3.9277e-01,  4.1505e-02, -1.1195e-01, -2.2224e-02,
#           2.7661e-01,  1.6826e-03,  4.6590e-01, -2.8672e-01,  3.7847e-01,
#          -1.2805e-01,  1.6038e-01, -8.3742e-03,  3.2522e-01],
#         [ 2.6507e-01, -5.5206e-01,  9.4760e-02, -3.7688e-01, -6.4006e-01,
#          -2.1131e-02,  1.7050e-01, -5.6312e-02, -2.0993e-01, -7.9626e-03,
#           6.3635e-03, -6.8070e-02,  1.7037e-01, -3.1631e-01,  2.7287e-01,
#           1.6674e-01,  6.8627e-01,  3.9188e-01, -7.3335e-02, -4.0857e-03,
#          -2.5581e-01,  3.1839e-01, -9.8696e-02,  3.8147e-02, -2.7304e-01,
#           1.9388e-01,  7.1618e-02, -1.2960e-01, -4.0737e-02,  1.0413e-01,
#           7.2243e-02,  1.6412e-01,  6.4922e-01, -3.9034e-01, -5.9993e-01,
#           9.8018e-02, -5.2538e-02, -1.2773e-01, -3.6129e-01,  1.3127e-01,
#           3.0038e-02,  1.7892e-01,  2.6631e-02, -9.3991e-02, -4.8645e-01,
#          -7.1493e-02, -2.6316e-01,  6.6285e-02,  1.3079e-01,  2.9000e-01,
#          -3.1026e-01,  8.1577e-02, -1.0445e-01,  1.8652e-01, -1.3410e-01,
#          -6.8425e-02,  2.1792e-01,  7.0915e-01, -1.9627e-01,  8.6023e-02,
#          -9.6193e-02, -1.7918e-01, -1.6643e-01,  8.5477e-02, -2.8607e-01,
#           3.0995e-01,  1.0656e-01,  9.3561e-03, -3.6717e-01,  3.4667e-02,
#          -1.6120e-01,  2.0854e-01,  2.4791e-01, -2.3543e-01,  4.4520e-03,
#          -5.8938e-02,  3.1021e-01, -4.2759e-01, -1.4118e-01, -3.8342e-02,
#           1.6334e-01, -4.0225e-02, -2.3822e-01, -2.7341e-01,  3.4271e-01,
#          -2.1576e-01, -3.8099e-01,  1.8543e-01, -4.3060e-01, -3.1543e-01,
#          -5.9798e-01,  5.9903e-01,  2.4901e-02,  3.2405e-01,  6.5766e-01,
#           4.0162e-01,  1.2822e-01, -5.6185e-02,  2.3245e-02,  1.5818e+00,
#           3.5782e-02,  1.4396e-01,  8.4039e-02, -1.9405e-01,  3.1346e-02,
#          -2.4534e-01, -3.9644e-02,  2.9711e-01,  2.0256e-02,  1.0066e-02,
#           1.1152e-01, -2.1608e-01, -1.9847e-01,  2.0703e-01,  1.8279e-01,
#           9.7936e-02, -7.9033e-03,  4.2476e-01, -1.1861e-02, -1.2741e-01,
#          -3.3234e-02, -3.8174e-01, -6.4115e-02, -1.1880e-01,  1.5879e-01,
#          -6.0128e-01,  2.9040e-01, -5.8722e-02,  8.2062e-02,  4.6768e-01,
#           3.0359e-01, -2.9171e-01,  5.0170e-01,  2.8315e-01, -5.8116e-01,
#          -1.8369e-01,  4.0764e-01,  4.4402e-01,  3.1791e-01, -2.0610e-01,
#          -3.1428e-01, -4.4746e-02, -1.5678e-01, -5.7131e-01, -5.4548e-01,
#          -1.3416e-01, -6.4144e-01, -4.1123e-02,  7.5760e-02,  4.5259e-02,
#           1.0597e-01, -8.2507e-02,  4.1639e-01, -1.8265e-01,  1.7213e-01,
#          -2.0813e-02,  3.8221e-01, -2.0980e-02,  2.3402e-02,  6.3549e-02,
#          -3.0255e-01, -3.6349e-01, -3.1703e-02, -2.6291e-01, -4.8142e-01,
#           2.1945e-01, -2.8798e-01, -1.5023e-01,  7.6328e-02, -2.1494e-01,
#          -1.8599e-01, -1.4711e-03,  1.9140e-01, -6.1824e-03, -5.1129e-02,
#           9.1947e-02, -7.4133e-02,  4.6075e-02, -1.4304e-01, -1.2237e-01,
#          -1.3015e-02,  3.9476e-01,  5.4342e-02,  2.3751e-02,  1.3471e-01,
#           4.8286e-01,  1.4722e-01,  2.3880e-02,  1.9644e-01,  1.4584e-01,
#           3.9337e-01, -2.1740e-01, -2.7429e-02,  1.5477e-02, -1.3392e-01,
#          -6.0688e-01,  1.0484e-02, -3.2805e-01,  2.5712e-01, -3.2640e-03,
#          -5.0048e-01,  2.7912e-02,  2.1796e-01,  2.5387e-01,  2.9345e-01,
#          -1.8422e-01,  2.4644e-01,  2.6597e-01, -4.0788e-01,  1.4252e-01,
#          -2.3676e-01,  1.7061e-01,  2.2253e-01,  6.9222e-02, -3.2927e-01,
#          -3.3005e-01,  1.3054e-01, -5.0251e-02, -4.6150e-01,  2.0644e-01,
#          -3.3856e-01, -4.1353e-01,  2.0242e-01, -5.6727e-01,  2.9533e-01,
#           2.8819e-01, -6.4560e-02,  6.3972e-01, -1.0889e-01,  3.0096e-01,
#           1.8287e-01,  1.8408e-01,  9.9823e-02, -1.0878e-01,  2.0514e-01,
#          -1.2581e-01, -2.2815e-01,  1.3397e-01, -8.9352e-03, -5.8735e-02,
#          -6.5719e-02, -1.6271e-01,  5.5115e-01,  1.7269e-01,  2.0962e-01,
#          -2.9873e-01,  9.4894e-02,  5.2337e-01, -6.4567e-01,  2.4070e-01,
#          -6.3286e-01,  1.7829e-01, -1.1203e-01,  3.0931e-02,  3.3806e-01,
#          -1.2584e-02, -1.4251e-01,  5.5577e-02,  1.1516e-01,  4.6821e-01,
#           3.7046e-01, -2.7749e-01, -3.8174e-01,  1.1501e-01,  2.4798e-01,
#          -1.4867e-01, -8.6114e-02,  2.1159e-01, -3.3749e-01,  1.0874e-01,
#          -3.5341e-01,  5.4316e-02, -3.3857e-01, -3.4588e-02,  4.2431e-01,
#           7.3156e-02, -6.4356e-02, -1.5806e-01, -2.7243e-01,  2.4568e-02,
#          -1.2479e-01, -5.3799e-01,  4.7151e-02,  3.5253e-01,  1.4937e-01,
#          -4.2757e-02, -2.3947e-01, -4.6855e-01,  1.8859e-01,  4.0358e-01,
#           5.7924e-02,  2.9453e-01,  1.9158e-01,  1.3211e-01, -1.3703e-01,
#           5.1749e-02,  5.0549e-02,  2.9647e-01,  2.2449e-02,  3.7559e-02,
#          -1.2489e-01, -4.0371e-01, -2.4724e-01,  8.4934e-02,  7.2083e-02,
#           4.7218e-02, -3.3309e-01, -2.5267e-01, -3.2180e-02,  3.1400e-01,
#          -8.8463e-02, -4.0895e-02, -1.4900e-01,  7.9782e-02,  1.9567e-02,
#           5.2375e-01,  2.0585e-01,  5.2710e-02, -1.6432e-01, -5.1954e-01,
#          -6.2153e-02,  1.1405e-01, -2.3139e-01, -4.8029e-01, -2.0362e-01,
#          -5.0144e-01, -1.8847e-01, -7.3658e-01, -2.3000e-01, -2.9199e-01,
#           6.7515e-02, -2.7328e-01, -4.2425e-01, -4.2273e-02,  3.6025e-01,
#           4.8095e-01, -3.8908e-01,  6.9508e-02, -5.2116e-02, -2.8321e-01,
#           4.5448e-01,  2.5071e-01,  8.8408e-02,  8.4512e-03,  7.1526e-02,
#           6.6195e-02,  2.9074e-01, -8.4818e-02, -2.3476e-01, -4.1152e-01,
#          -1.9413e-01,  6.5689e-01, -3.3887e-01, -3.9840e-01,  1.0812e-01,
#          -7.9120e-02, -2.3356e-01, -4.5715e-02, -1.1004e-01,  2.1660e-01,
#           3.1551e-01,  3.6689e-01, -3.2978e-01,  1.0964e-01,  2.7055e-02,
#          -2.9354e-01,  3.8541e-01, -1.3937e-03,  7.2465e-02,  2.3548e-01,
#           1.1280e-01,  2.4180e-01, -1.8581e-01,  1.0845e-01, -3.9313e-02,
#           1.8329e-01, -1.3458e-01,  3.4462e-01, -4.8473e-02,  5.7098e-02,
#           2.2582e-01,  3.4709e-01,  1.6021e-01,  4.6794e-01]])

# %%
len(result)
# Out:
# 2

# %%
score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))

# %%
score[0][0]
# Out:
# 0.7417778

# %%
def similarity_calc(input1,input2):
    result = embeding_calc([input1,input2])
    score = cosine_similarity(result[0].reshape(1, -1),result[1].reshape(1, -1))
    return score[0][0]

# %%
similarity_calc('balanced sound','poor bose')
# Out:
# 0.16619003

# %% [markdown]
# # Data processing

# %%
df = pd.read_csv('/home/heptagon/Desktop/nps_review_analysis/dataset/amazon_mobile_review_topic.csv')
df.head()
# Out:
#                                             comments  \
# 0  The phone looks like it was brand new everythi...
# 1  This shipped so fast and my son was so excited...
# 2  I am very pleased with my phone It was in grea...
# 3  First off this is NOT a verizon phone I put th...
# 4  This phone is advertised as Verizon it DOES NO...
#
#                                                topic sentiment          type
# 0  phone look, no scratch, scratch shipping, arri...  POSITIVE   information
# 1  shipped fast excited son, great condition phon...  POSITIVE  appreciation
# 2             pleased great working affordable shape  POSITIVE  appreciation
# 3  verizon phone, verizon sim card, cell service,...  NEGATIVE   information
# 4       verizon account, huge waste time, time money  NEGATIVE   information

# %%
all_keyword = []
for key_str in tqdm(df.topic):
#     print(key_str)
    splited_str = key_str.split(',')
    if len(splited_str)>0:
        all_keyword += splited_str
#     break

all_keyword
# Out:
# 100%|█████████████████████████████████████| 314/314 [00:00<00:00, 258186.92it/s]
# ['phone look',
#  ' no scratch',
#  ' scratch shipping',
#  ' arrived time',
#  ' great unlocked work',
#  ' perfect mexican carrier',
#  ' sure using problem',
#  ' u mobile',
#  'shipped fast excited son',
#  ' great condition phone',
#  ' money thanks',
#  ' fast shipping',
#  'pleased great working affordable shape',
#  'verizon phone',
#  ' verizon sim card',
#  ' cell service',
#  ' serial number',
#  ' agian phone',
#  'verizon account',
#  ' huge waste time',
#  ' time money',
#  'nice phone paid price',
#  ' sent review',
#  'gizmo trader',
#  ' scratch good company',
#  ' described better product',
#  'button mess',
#  ' mess lot',
#  'great seller',
#  ' work version',
#  ' many version problem',
#  'apple product',
#  ' product rep verizon store',
#  ' phone verizon',
#  ' verizon system',
#  ' closer inspection',
#  ' home button',
#  ' correct center',
#  ' center body phone',
#  ' dealing phone process',
#  ' refund purchase',
#  ' different supplier',
#  'great minor scratch',
#  ' fine battery short life',
#  ' daily overall good major problem charger',
#  ' phone work',
#  ' free second one',
#  ' old charger',
#  'advertised apple iphone',
#  ' store insert sim card',
#  ' card work',
#  ' no complaint',
#  'phone type',
#  ' type freeze',
#  'fast shipping phone look',
#  'great product',
#  'ready connected updated month',
#  ' phone screen',
#  ' no touch screen',
#  ' obvious recieved replaced screen',
#  'month phone earpiece',
#  ' worked earpiece work',
#  'disappointed speaker work',
#  'home button',
#  ' button working mind',
#  'iphone manner phone work',
#  'phone perfect',
#  'no received trouble',
#  'first phone',
#  ' original box',
#  ' new shipped device',
#  ' either charger',
#  ' original box',
#  ' neither phone',
#  ' original accessory',
#  ' charger replacement',
#  ' plugged pop',
#  ' original correct charger',
#  ' nothing phone',
#  ' purchasing seller',
#  'phone thankyiu',
#  'purchased unit gift',
#  ' warranty replacement',
#  ' blue original seller',
#  ' pink put iphone',
#  ' blue cover',
#  ' cover apple perspective',
#  ' void warranty',
#  ' warranty lesson',
#  ' phone seller',
#  'advertised excellent condition',
#  ' scratch screen',
#  ' screen pop',
#  ' fake mispelled word',
#  ' disappointed product',
#  'spankin lightning loose port',
#  ' replacement stat',
#  'received phone',
#  'messed glitch count',
#  'phone work',
#  ' fine charger',
#  'exceeded expectation',
#  'good charge',
#  'fast work',
#  'great good item including description',
#  ' photo purchased kudos',
#  ' great work',
#  'good work',
#  ' iphone flawless',
#  'looked work',
#  ' refurbished phone seller',
#  ' answered question',
#  'much service',
#  ' phone service excellent',
#  ' new product',
#  ' excellent price',
#  ' love go carrier',
#  ' another party cost',
#  ' excellent friend',
#  ' monthly friend family member',
#  ' direct putting thank',
#  ' much amazon',
#  ' big smile',
#  'great exterior condition screen',
#  ' pink line',
#  'extra charging malfunction',
#  ' charging use',
#  ' much tape case',
#  ' happy phone',
#  'great great condition',
#  ' great ordering experience',
#  ' new phone thank',
#  'tact phone',
#  ' apple logo screen',
#  ' option hardware',
#  ' hardware problem',
#  ' exhausted problem phone',
#  ' turned disappointing high hope',
#  ' test luck',
#  'phone place',
#  ' green silicone',
#  ' second iphone phone',
#  'small working issue',
#  ' p button',
#  ' cost beat',
#  'new little iphone apple',
#  ' bad program',
#  ' itunes account',
#  ' get apps',
#  'replacement son',
#  ' son phone',
#  ' getting issue',
#  ' set phone fault',
#  ' new sim card',
#  ' broke store',
#  ' price replacement',
#  ' thrilled full replacement phone',
#  ' face time',
#  ' time friend',
#  'super fast shipping',
#  'wifi device',
#  ' month purchase',
#  'phone couple',
#  ' apple store',
#  'great looking working',
#  ' no scratch',
#  ' specific seller',
#  ' seller review',
#  'whole day',
#  ' day power button',
#  ' button faulty',
#  'love phone',
#  ' verizon phone',
#  ' customer rep phone',
#  ' long time',
#  ' verizon customer',
#  ' time customer year',
#  ' t service',
#  ' big mistake',
#  ' long negative story',
#  ' verizon iphone',
#  ' verizon charge',
#  ' charge month',
#  ' new service',
#  ' stupid lied refuse',
#  ' verizon type',
#  'c gb storage',
#  ' ordered phone',
#  ' no problem',
#  ' plenty good deal price',
#  'needed phone',
#  'verizon network',
#  'failed recharging repairable purchase',
#  ' new phone',
#  ' phone apple',
#  ' apple ver',
#  ' new phone',
#  'standing joke',
#  ' apple iphone',
#  ' color phone',
#  ' sim card',
#  ' verizon store',
#  ' store activate',
#  ' sim port',
#  ' earbuds charger',
#  ' apple icon',
#  ' port key standard icon sticker',
#  ' fun spring green',
#  ' week doorstep booted product',
#  ' fine worked month',
#  ' month processing',
#  ' next iphone',
#  ' couple month',
#  ' month ear piece',
#  ' returned seller refund',
#  ' restocking fee',
#  ' nice fun',
#  ' fun color',
#  ' color working',
#  ' worked working worth vendor',
#  'great price',
#  ' fast shipping work',
#  'apple kid phone',
#  ' android phone keep',
#  ' phone superb',
#  ' intuitive use',
#  ' use seller',
#  ' responsive reason',
#  ' new phone',
#  ' imei verification',
#  ' star sure standard seller star',
#  'want return',
#  ' descent value',
#  ' fortune phone',
#  'phone thank',
#  'verizon wireless phone',
#  ' verizon phone',
#  ' unable use',
#  ' lesser value',
#  'no sim card',
#  'seller service',
#  'bit phone',
#  ' phone excellent made condition',
#  ' easier bbrewer polite',
#  'purchasing experience',
#  ' excellent experience item',
#  ' original packaging',
#  ' new speedy shipping',
#  'needed enter pin',
#  ' anyonecan gime advice',
#  'awesome phone mine',
#  ' no scratch',
#  'scratch work',
#  'excited unlocked easy set',
#  ' noticeable damage scratch',
#  ' knew orginal charger',
#  ' last long charger',
#  ' mess play',
#  ' new charger charger reason',
#  'waste time',
#  ' apple store',
#  ' poor hour',
#  ' hour usage hour',
#  ' no added apps',
#  ' setting standard',
#  ' researching problem',
#  ' bad battery',
#  ' paid return seller',
#  ' screen protector',
#  ' worse battery life',
#  ' remove straight box',
#  ' hr recharge',
#  ' no added apps',
#  ' shipping money',
#  ' incompetent repair center',
#  ' replace kit wish',
#  'us screen protector',
#  ' protector day rest fine',
#  'heavy scratch',
#  'iphone unlocked factory',
#  ' net right',
#  ' paid iphone',
#  ' no scrape',
#  ' con charger',
#  ' no major scratch charger work',
#  ' dollar store',
#  ' deal price',
#  ' new good price looking pas',
#  'service product',
#  ' product world seller',
#  ' great seller brand',
#  'perfect condition',
#  ' unlocked argentina',
#  'advertised work',
#  ' telephone company',
#  'phone owning month',
#  ' life proof',
#  ' proof case',
#  ' phone screen',
#  ' loose software advertised problem',
#  ' new phone',
#  'dent corner',
#  'awesome phone',
#  ' brand factory unlocked gsm',
#  ' iphone gb',
#  ' screen protector',
#  'constant issue',
#  ' blue screen',
#  ' screen death',
#  ' multiple time',
#  ' time phone refuse',
#  ' refuse charge',
#  ' randomly shuts',
#  ' shuts screen',
#  ' phone people',
#  'thanks daughter',
#  'quick refund',
#  'hot use',
#  ' use phone',
#  'battery going percentage',
#  ' apple store',
#  ' store used find',
#  ' failing took software',
#  ' pas apple test',
#  ' failing bad software',
#  'good issue',
#  ' fake plastic',
#  'good condition',
#  'worst working mobile',
#  ' trust seller',
#  ' seller waste money',
#  'new unlocked item',
#  ' charger item',
#  ' new lot',
#  ' brand lot dust',
#  'stated verizon',
#  ' hour minute',
#  ' trying called figure',
#  'satisfied product',
#  ' early perfect loving condition',
#  ' new phone',
#  'fast delivery',
#  ' delivery thank',
#  'month iphone',
#  ' phone carpet',
#  ' carpet feat le protective case',
#  ' case starting reason',
#  ' wire pay',
#  ' fixed buy',
#  'good value',
#  ' value money gift',
#  'happy product',
#  'phone line',
#  ' line goin',
#  'excellent condition',
#  'great phone work',
#  'quick functioning product',
#  'able configure connecting trying working download',
#  ' apple server',
#  ' touch screen',
#  ' mobile repair',
#  ' repair store',
#  ' mobile bougth',
#  ' refurbished new mobile amazon',
#  ' mentioned first frustating experience',
#  ' seller checkednin',
#  ' mobile repair',
#  ' usd change screen',
#  ' gic problem',
#  'great condition',
#  ' iphone condition work',
#  ' no issue regarding concern',
#  'new put condition',
#  ' phone fine found beware',
#  ' read review',
#  'great phone work',
#  'advertised thank',
#  'good price',
#  ' great mobile',
#  'good buy',
#  'great condition work',
#  'water purchased damage',
#  ' new holding stop',
#  ' liquid indicator',
#  ' based activated serial',
#  'best thing',
#  'perfect little defecto screen',
#  ' resolve problem',
#  'phone iphone',
#  ' enough info',
#  'satisfied great phone',
#  ' recommend seller',
#  'expected accessory',
#  'efficient service',
#  'awesome happy product service',
#  'perfect great seller',
#  'no good iphone camera work',
#  ' d work',
#  ' another phone',
#  'great phone good work',
#  ' beautiful picture',
#  'sealed box',
#  ' apple service',
#  ' phone service center',
#  ' new contacted seller',
#  ' no apple warranty',
#  ' warranty repair',
#  'excellent phone',
#  ' phone needed return',
#  ' old phone',
#  ' past return date',
#  'good excellent condition',
#  'high quality',
#  ' prompt service',
#  ' happy purchase',
#  'samsung couple',
#  ' everyone family',
#  ' used great thing',
#  ' fastest phone',
#  ' several apps',
#  ' thumbprint password',
#  ' password feature',
#  ' miss swipe',
#  ' cool feature swipe typing',
#  ' phone perfect',
#  'phone boyfriend',
#  ' no complaint',
#  ' owned excellent condition',
#  'high end',
#  ' end tell',
#  ' good material',
#  ' material seller',
#  ' top notch product',
#  ' unlocked use',
#  'good mark',
#  ' wise phone work',
#  'good shipping product',
#  'phone work',
#  'nice term',
#  ' term worked mobile network',
#  'new work',
#  ' no complaint arrival',
#  'us screen protector',
#  ' protector day rest fine',
#  'died month return policy',
#  'bought gifted father',
#  ' local center',
#  ' total treachery',
#  'turn turn charge',
#  'hate thing',
#  ' n thing wife',
#  ' iphone birthday',
#  ' stand use',
#  ' mine home apple',
#  ' intuitive throw thing',
#  ' thing wall',
#  ' star fact',
#  ' mobile wife',
#  ' wife telling tolerates',
#  ' another iphone',
#  'good working condition',
#  'easy transfer',
#  ' transfer data iphone',
#  ' sim card',
#  ' new card phone',
#  'returned item',
#  ' no problem',
#  'matched description',
#  ' described look used iphones',
#  'excellent condition phone',
#  ' no good job',
#  'described unlocked husband',
#  ' old iphones',
#  ' sim card',
#  ' card work',
#  'new work',
#  'new function work',
#  'excellent item',
#  ' new work',
#  'good phone',
#  ' phone overall look',
#  ' no scratch front',
#  ' acceptable price',
#  'fine serve purpose',
#  'next phone amazon',
#  'great experience product',
#  ' good item',
#  ' new product',
#  ' product excellent seller',
#  'phone work',
#  ' new phone',
#  ' craigslist letgo',
#  'phone thanx',
#  ' best thanx man',
#  'emailed seller',
#  ' ready use',
#  ' needed turn',
#  ' new scuff top',
#  ' no scratch crack',
#  ' mentioned seller',
#  ' sim card',
#  ' card phone',
#  ' call phone company',
#  ' great seller',
#  ' great product',
#  'seller factory unlock phone',
#  ' unlocked checked apple',
#  ' professional locked',
#  ' no answer',
#  ' unlocked iphone work',
#  ' unlocked phone work',
#  ' work tell beware',
#  ' iphone factory',
#  'great condition work',
#  'perfect condition',
#  ' no complaint',
#  'great gift',
#  'expected good product',
#  'telephone lot',
#  ' lot scratch screen',
#  'good condition',
#  'phone networking',
#  ' networking problem',
#  ' problem time network',
#  ' want return',
#  'sealed apple box',
#  ' new odd thing',
#  ' checked apple warranty',
#  ' customer guaranteed service',
#  ' new another small thing',
#  ' language apps',
#  ' many sub menu',
#  ' primary language',
#  ' language english',
#  ' spanish second language',
#  ' chinese sign',
#  'super fast delivery',
#  ' excellent excellent phone',
#  'screw plate',
#  ' plate top',
#  ' lcd connector',
#  ' missing top bad condition',
#  'new condition',
#  ' great hold',
#  ' good charge',
#  ' no using issue',
#  ' tmobile delivery',
#  ' delivery prompt',
#  'iphone unlocked factory',
#  ' net right',
#  ' paid iphone',
#  ' no scrape',
#  ' con charger',
#  ' no major scratch charger work',
#  ' dollar store',
#  ' deal price',
#  ' new good price looking pas',
#  'service product',
#  ' product world seller',
#  ' great seller brand',
#  'perfect condition',
#  ' unlocked argentina',
#  'advertised work',
#  ' telephone company',
#  'defective start waste money',
#  'good issue',
#  ' fake plastic',
#  'worst working mobile',
#  ' trust seller',
#  ' seller waste money',
#  'new unlocked item',
#  ' charger item',
#  ' new lot',
#  ' brand lot dust',
#  'stated verizon',
#  ' hour minute',
#  ' trying called figure',
#  'satisfied product',
#  ' early perfect loving condition',
#  ' new phone',
#  'fast delivery',
#  ' delivery thank',
#  'month iphone',
#  ' phone carpet',
#  ' carpet feat le protective case',
#  ' case starting reason',
#  ' wire pay',
#  ' fixed buy',
#  'purchasing experience',
#  ' excellent experience item',
#  ' original packaging',
#  ' new speedy shipping',
#  'needed enter pin',
#  ' anyonecan gime advice',
#  'awesome phone mine',
#  ' no scratch',
#  'excited unlocked easy set',
#  ' noticeable damage scratch',
#  ' knew orginal charger',
#  ' last long charger',
#  ' mess play',
#  ' new charger charger reason',
#  'waste time',
#  ' apple store',
#  ' poor hour',
#  ' hour usage hour',
#  ' no added apps',
#  ' setting standard',
#  ' researching problem',
#  ' bad battery',
#  ' paid return seller',
#  ' screen protector',
#  ' worse battery life',
#  ' remove straight box',
#  ' hr recharge',
#  ' no added apps',
#  ' shipping money',
#  ' incompetent repair center',
#  ' replace kit wish',
#  'day earlyer',
#  ' time order',
#  ' order phone brand',
#  ' new original package',
#  'good value',
#  ' value money gift',
#  'happy product',
#  'battery going percentage',
#  ' apple store',
#  ' store used find',
#  ' failing took software',
#  ' pas apple test',
#  ' failing bad software',
#  'phone owning month',
#  ' life proof',
#  ' proof case',
#  ' phone screen',
#  ' loose software advertised problem',
#  ' new phone',
#  'dent corner',
#  'awesome phone',
#  ' brand factory unlocked gsm',
#  ' iphone gb',
#  ' screen protector',
#  'constant issue',
#  ' blue screen',
#  ' screen death',
#  ' multiple time',
#  ' time phone refuse',
#  ' refuse charge',
#  ' randomly shuts',
#  ' shuts screen',
#  ' phone people',
#  'thanks daughter',
#  'quick refund',
#  'hot use',
#  ' use phone',
#  'heavy scratch',
#  'better deal',
#  'fake apple product',
#  'supposed problem payment',
#  ' visa camera',
#  ' work upsetting',
#  'slow many ipads',
#  'good shapthanks',
#  'awesome great condition',
#  ' great buy seller',
#  'great basic design',
#  ' newer model',
#  ' compatible icloud',
#  ' contact icloud',
#  ' apps version app',
#  ' st generation',
#  ' generation iphone itunes',
#  ' want download',
#  ' older compatible version',
#  ' work phone',
#  ' phone course',
#  'great condition',
#  ' buy condition battery brand',
#  ' new hold day',
#  ' classic phone',
#  'slight damage dayle',
#  ' tear phone',
#  ' big chunk',
#  ' whole bottom corner',
#  ' effected screen charger',
#  ' phone work',
#  ' little smaller dime',
#  ' no charger',
#  ' new charger',
#  ' brand charger charging trouble',
#  ' charger port',
#  'g work',
#  ' basic cool hold',
#  ' right amount',
#  'amazon people',
#  ' good com stuff',
#  ' cheap skeptical',
#  ' shop line',
#  ' debit card',
#  ' amazon com',
#  ' iphone son',
#  ' much need',
#  ' school birthday',
#  ' happy happy thanks',
#  'g work iphone',
#  ' well ring volume',
#  ' sim chip',
#  ' iphone condition',
#  ' condition phone ring',
#  ' better quality control',
#  'jailbreak unlock',
#  ' good phone price',
#  ' every experience',
#  'no compatible verizon',
#  ' old way',
#  'great work',
#  ' looking frozen start screen',
#  ' subsidiary warehouse',
#  ' placed order warehouse deal warehouse',
#  ' warehouse deal inventory',
#  ' unable replace order',
#  ' printer print return',
#  ' return label',
#  ' bussiness day',
#  ' day money',
#  'new condition problem',
#  ' outdated iphone',
#  ' newest generation',
#  ' good bargain',
#  'plugged charger',
#  ' current charge iphone',
#  ' dead phone',
#  ' iphone box',
#  ' signed year',
#  ' year contract',
#  ' new contract time',
#  ' mess phone light',
#  ' light scratch',
#  'love phone',
#  'disappointed phone',
#  'gift work',
#  ' work return',
#  ' pasted day',
#  ' day policy lesson',
#  'water damage',
#  'broken thought',
#  ' good condition',
#  ' phone charger',
#  ' different seller',
#  'no internet',
#  ' no apps',
#  'phone use',
#  ' durable phone grandson',
#  'cost money',
#  ' unlocked money speaker',
#  'liked iphone place',
#  ' music download',
#  ' download apps',
#  'advertised function',
#  ' basic phone',
#  ' camera surf',
#  ' simple used surf web',
#  'able unlocked verizon',
#  ' complete waste money',
#  'new phone',
#  'shipping iphone',
#  ' great condition',
#  ' volume button',
#  ' missing button crack',
#  ' sim card',
#  'cell phone',
#  'perfect condition',
#  ' nervous buying condition love',
#  'itthe cheap useablei',
#  'worst bought thing',
#  ' broke month',
#  ' lit fire',
#  'pay shop fix',
#  ' bad phone',
#  ' see problem',
#  ' missing screw',
#  ' assembled mute button',
#  'phone work',
#  'good condition screen',
#  ' perfect thing',
#  ' unlock use',
#  ' use sim card',
#  ' extra fee unlock',
#  'waste money',
#  ' huge money selling shame',
#  ' unusable ripping',
#  'operating system',
#  ' system apps',
#  ' grocery store',
#  ' local store weather channel',
#  ' older apps',
#  'rate item',
#  'used defective iphone',
#  ' description contacted monsterbuyback',
#  ' speedy return',
#  ' cooperative apologized great company',
#  ' reputable trustworthy thanks',
#  'great shape',
#  ' great devilery',
#  'good precio envio servicio empaque',
#  ' grande peque buena',
#  ' buena comunicacion',
#  'good amazon',
#  'good condition',
#  ' no problem product',
#  ' seller godblessxoxo',
#  'phone friend',
#  ' terrible scratch',
#  ' many different company',
#  'great use',
#  ' product word',
#  ' overall satisfied word place telling holder',
#  'phone calling work',
#  ' feature camera',
#  ' camera web',
#  ' emergency purpose',
#  ' ok phone',
#  ' feature use',
#  ' use car',
#  'prepaid att service',
#  'second phone',
#  ' unlocked returned expense',
#  ' sure order',
#  ' happy box',
#  ' unlocked order',
#  ' send want',
#  'phone feature',
#  ' feature price',
#  ' comfortable recommending fact',
#  ' friend moment',
#  ' moment thing',
#  ' locked thought',
#  ' complete review',
#  'no sim card',
#  ' video store',
#  ' store telephone number',
#  'best phone',
#  ' good value price',
#  'new cell',
#  ' multiple registration number',
#  ' refunded whole thing',
#  ' many problem',
#  'phone point',
#  ' point apps',
#  ' old old phone',
#  ' newer version wtf',
#  'research buying',
#  ' upgradeable grandson day',
#  ' day thing',
#  'decent shape owner',
#  ' old otterbox',
#  ' charged unplugged charger',
#  ' unusable school',
#  ' net prepaid held learned phone',
#  ' guess lesson',
#  ' used iphones',
#  ' terrible amazon',
#  ' product defectiveness',
#  ' used defectiveness shipment',
#  'open program',
#  ' program running background',
#  'puchase vintage',
#  ' happy vintage fun phone',
#  'nice item',
#  ' nice item',
#  ' expected item gift',
#  'no belief',
#  ' new good condition',
#  'no apps',
#  'damaging telefonolo',
#  ' phone fraud',
#  'good condition',
#  'phone activate',
#  ' phone screen',
#  'call horrible phone',
#  'good new product publication',
#  'described work',
#  ' new charger',
#  ' pleased purchase thank',
#  'piece screen',
#  ' total disaster',
#  ' sell phone',
#  'great condition',
#  ' satisfied purchase',
#  ' honest supplierhowever',
#  ' supplierhowever know',
#  ' download apps',
#  ' supplier messed purchased used thing',
#  ' apple phone',
#  ' new work',
#  ' sim card',
#  ' card slot',
#  ' great slot internet work',
#  'star item',
#  ' described seller',
#  ' every one',
#  'great love',
#  ' form u',
#  ' great condition',
#  'phone great condition',
#  ' star rating',
#  ' phone apps',
#  ' disabled upgrade',
#  ' application phone',
#  ' good calling texting',
#  ' searching web',
#  ' great deal',
#  'worst iphone',
#  ' phone paperweight',
#  ' paperweight phone',
#  ' many problem',
#  ' apps phone',
#  ' major apps',
#  ' facebook twitter',
#  ' fourth apps',
#  ' took day',
#  ' searching apps',
#  ' internet phone',
#  ' phone static',
#  ' static sound',
#  ' phone call',
#  ' slow long load',
#  ' faster phone problem',
#  ' cheap problem phone',
#  ' weird clicking noise unlock phone phone',
#  ' another account',
#  ' download music',
#  ' music erase',
#  ' tried erase phone start',
#  ' app store',
#  ' another email',
#  ' wanted phone',
#  ' contact seller',
#  ' seller return phone',
#  ' going reply',
#  ' reset setting turn',
#  ' phone advice',
#  ' advice purchase',
#  ' back purchase iphone',
#  ' higher money',
#  ' samsung phone',
#  ' good ipod player',
#  ' good good digital picture frame',
#  ' child game',
#  ' actual phone',
#  ' phone stay',
#  'time trip',
#  ' costed extra unlocked unit',
#  ' no big thought deal',
#  ' great condition',
#  ' description thank',
#  'perfect used item',
#  ' r firmware',
#  ' firmware work',
#  ' described whited excellent thank',
#  'new apps',
#  ' backup phone music',
#  ' basic music player',
#  'lit ringer button move',
#  'good condition',
#  ' phone condition problem',
#  ' sim card',
#  ' work phone',
#  ' sim card',
#  ' much getting problem',
#  'phone sim card',
#  ' card tray',
#  ' another sim tray',
#  ' pay store',
#  ' tray store fix waste money',
#  ' money scam',
#  'sensitive phone',
#  ' unintended contact phone',
#  ' outstanding meet expectation',
#  'expected lot',
#  'fantastic condition problem',
#  ' problem miss iphone',
#  ' old support apps',
#  ' excellent product',
#  ' product work',
#  ' ammended product',
#  'known apple',
#  ' no apps software',
#  ' money useless device',
#  'fine week',
#  ' week turn',
#  ' battery point',
#  ' new iphone',
#  'unlock phone',
#  ' unlocked son',
#  'turned perfect gift',
#  ' expected work',
#  'visible front clean delivery',
#  ' perfect good price',
#  ...]

# %%
freq_count = {}
for key in all_keyword:
    if key in freq_count:
        freq_count[key] +=1
    else:
        freq_count[key] = 1

# %%
len(freq_count)
# Out:
# 993

# %%
freq_count
# Out:
# {'phone look': 1,
#  ' no scratch': 4,
#  ' scratch shipping': 1,
#  ' arrived time': 1,
#  ' great unlocked work': 1,
#  ' perfect mexican carrier': 1,
#  ' sure using problem': 1,
#  ' u mobile': 1,
#  'shipped fast excited son': 1,
#  ' great condition phone': 1,
#  ' money thanks': 1,
#  ' fast shipping': 1,
#  'pleased great working affordable shape': 1,
#  'verizon phone': 1,
#  ' verizon sim card': 1,
#  ' cell service': 1,
#  ' serial number': 1,
#  ' agian phone': 1,
#  'verizon account': 1,
#  ' huge waste time': 1,
#  ' time money': 1,
#  'nice phone paid price': 1,
#  ' sent review': 1,
#  'gizmo trader': 1,
#  ' scratch good company': 1,
#  ' described better product': 1,
#  'button mess': 1,
#  ' mess lot': 1,
#  'great seller': 1,
#  ' work version': 1,
#  ' many version problem': 1,
#  'apple product': 1,
#  ' product rep verizon store': 1,
#  ' phone verizon': 1,
#  ' verizon system': 1,
#  ' closer inspection': 1,
#  ' home button': 1,
#  ' correct center': 1,
#  ' center body phone': 1,
#  ' dealing phone process': 1,
#  ' refund purchase': 1,
#  ' different supplier': 1,
#  'great minor scratch': 1,
#  ' fine battery short life': 1,
#  ' daily overall good major problem charger': 1,
#  ' phone work': 2,
#  ' free second one': 1,
#  ' old charger': 1,
#  'advertised apple iphone': 1,
#  ' store insert sim card': 1,
#  ' card work': 2,
#  ' no complaint': 3,
#  'phone type': 1,
#  ' type freeze': 1,
#  'fast shipping phone look': 1,
#  'great product': 1,
#  'ready connected updated month': 1,
#  ' phone screen': 4,
#  ' no touch screen': 1,
#  ' obvious recieved replaced screen': 1,
#  'month phone earpiece': 1,
#  ' worked earpiece work': 1,
#  'disappointed speaker work': 1,
#  'home button': 1,
#  ' button working mind': 1,
#  'iphone manner phone work': 1,
#  'phone perfect': 1,
#  'no received trouble': 1,
#  'first phone': 1,
#  ' original box': 2,
#  ' new shipped device': 1,
#  ' either charger': 1,
#  ' neither phone': 1,
#  ' original accessory': 1,
#  ' charger replacement': 1,
#  ' plugged pop': 1,
#  ' original correct charger': 1,
#  ' nothing phone': 1,
#  ' purchasing seller': 1,
#  'phone thankyiu': 1,
#  'purchased unit gift': 1,
#  ' warranty replacement': 1,
#  ' blue original seller': 1,
#  ' pink put iphone': 1,
#  ' blue cover': 1,
#  ' cover apple perspective': 1,
#  ' void warranty': 1,
#  ' warranty lesson': 1,
#  ' phone seller': 1,
#  'advertised excellent condition': 1,
#  ' scratch screen': 1,
#  ' screen pop': 1,
#  ' fake mispelled word': 1,
#  ' disappointed product': 1,
#  'spankin lightning loose port': 1,
#  ' replacement stat': 1,
#  'received phone': 1,
#  'messed glitch count': 1,
#  'phone work': 4,
#  ' fine charger': 1,
#  'exceeded expectation': 1,
#  'good charge': 1,
#  'fast work': 1,
#  'great good item including description': 1,
#  ' photo purchased kudos': 1,
#  ' great work': 1,
#  'good work': 1,
#  ' iphone flawless': 1,
#  'looked work': 1,
#  ' refurbished phone seller': 1,
#  ' answered question': 1,
#  'much service': 1,
#  ' phone service excellent': 1,
#  ' new product': 2,
#  ' excellent price': 1,
#  ' love go carrier': 1,
#  ' another party cost': 1,
#  ' excellent friend': 1,
#  ' monthly friend family member': 1,
#  ' direct putting thank': 1,
#  ' much amazon': 1,
#  ' big smile': 1,
#  'great exterior condition screen': 1,
#  ' pink line': 1,
#  'extra charging malfunction': 1,
#  ' charging use': 1,
#  ' much tape case': 1,
#  ' happy phone': 1,
#  'great great condition': 1,
#  ' great ordering experience': 1,
#  ' new phone thank': 1,
#  'tact phone': 1,
#  ' apple logo screen': 1,
#  ' option hardware': 1,
#  ' hardware problem': 1,
#  ' exhausted problem phone': 1,
#  ' turned disappointing high hope': 1,
#  ' test luck': 1,
#  'phone place': 1,
#  ' green silicone': 1,
#  ' second iphone phone': 1,
#  'small working issue': 1,
#  ' p button': 1,
#  ' cost beat': 1,
#  'new little iphone apple': 1,
#  ' bad program': 1,
#  ' itunes account': 1,
#  ' get apps': 1,
#  'replacement son': 1,
#  ' son phone': 1,
#  ' getting issue': 1,
#  ' set phone fault': 1,
#  ' new sim card': 1,
#  ' broke store': 1,
#  ' price replacement': 1,
#  ' thrilled full replacement phone': 1,
#  ' face time': 1,
#  ' time friend': 1,
#  'super fast shipping': 1,
#  'wifi device': 1,
#  ' month purchase': 1,
#  'phone couple': 1,
#  ' apple store': 5,
#  'great looking working': 1,
#  ' specific seller': 1,
#  ' seller review': 1,
#  'whole day': 1,
#  ' day power button': 1,
#  ' button faulty': 1,
#  'love phone': 2,
#  ' verizon phone': 2,
#  ' customer rep phone': 1,
#  ' long time': 1,
#  ' verizon customer': 1,
#  ' time customer year': 1,
#  ' t service': 1,
#  ' big mistake': 1,
#  ' long negative story': 1,
#  ' verizon iphone': 1,
#  ' verizon charge': 1,
#  ' charge month': 1,
#  ' new service': 1,
#  ' stupid lied refuse': 1,
#  ' verizon type': 1,
#  'c gb storage': 1,
#  ' ordered phone': 1,
#  ' no problem': 3,
#  ' plenty good deal price': 1,
#  'needed phone': 1,
#  'verizon network': 1,
#  'failed recharging repairable purchase': 1,
#  ' new phone': 8,
#  ' phone apple': 1,
#  ' apple ver': 1,
#  'standing joke': 1,
#  ' apple iphone': 1,
#  ' color phone': 1,
#  ' sim card': 10,
#  ' verizon store': 1,
#  ' store activate': 1,
#  ' sim port': 1,
#  ' earbuds charger': 1,
#  ' apple icon': 1,
#  ' port key standard icon sticker': 1,
#  ' fun spring green': 1,
#  ' week doorstep booted product': 1,
#  ' fine worked month': 1,
#  ' month processing': 1,
#  ' next iphone': 1,
#  ' couple month': 1,
#  ' month ear piece': 1,
#  ' returned seller refund': 1,
#  ' restocking fee': 1,
#  ' nice fun': 1,
#  ' fun color': 1,
#  ' color working': 1,
#  ' worked working worth vendor': 1,
#  'great price': 1,
#  ' fast shipping work': 1,
#  'apple kid phone': 1,
#  ' android phone keep': 1,
#  ' phone superb': 1,
#  ' intuitive use': 1,
#  ' use seller': 1,
#  ' responsive reason': 1,
#  ' imei verification': 1,
#  ' star sure standard seller star': 1,
#  'want return': 1,
#  ' descent value': 1,
#  ' fortune phone': 1,
#  'phone thank': 1,
#  'verizon wireless phone': 1,
#  ' unable use': 1,
#  ' lesser value': 1,
#  'no sim card': 2,
#  'seller service': 1,
#  'bit phone': 1,
#  ' phone excellent made condition': 1,
#  ' easier bbrewer polite': 1,
#  'purchasing experience': 2,
#  ' excellent experience item': 2,
#  ' original packaging': 2,
#  ' new speedy shipping': 2,
#  'needed enter pin': 2,
#  ' anyonecan gime advice': 2,
#  'awesome phone mine': 2,
#  'scratch work': 1,
#  'excited unlocked easy set': 2,
#  ' noticeable damage scratch': 2,
#  ' knew orginal charger': 2,
#  ' last long charger': 2,
#  ' mess play': 2,
#  ' new charger charger reason': 2,
#  'waste time': 2,
#  ' poor hour': 2,
#  ' hour usage hour': 2,
#  ' no added apps': 4,
#  ' setting standard': 2,
#  ' researching problem': 2,
#  ' bad battery': 2,
#  ' paid return seller': 2,
#  ' screen protector': 4,
#  ' worse battery life': 2,
#  ' remove straight box': 2,
#  ' hr recharge': 2,
#  ' shipping money': 2,
#  ' incompetent repair center': 2,
#  ' replace kit wish': 2,
#  'us screen protector': 2,
#  ' protector day rest fine': 2,
#  'heavy scratch': 2,
#  'iphone unlocked factory': 2,
#  ' net right': 2,
#  ' paid iphone': 2,
#  ' no scrape': 2,
#  ' con charger': 2,
#  ' no major scratch charger work': 2,
#  ' dollar store': 2,
#  ' deal price': 2,
#  ' new good price looking pas': 2,
#  'service product': 2,
#  ' product world seller': 2,
#  ' great seller brand': 2,
#  'perfect condition': 4,
#  ' unlocked argentina': 2,
#  'advertised work': 2,
#  ' telephone company': 2,
#  'phone owning month': 2,
#  ' life proof': 2,
#  ' proof case': 2,
#  ' loose software advertised problem': 2,
#  'dent corner': 2,
#  'awesome phone': 2,
#  ' brand factory unlocked gsm': 2,
#  ' iphone gb': 2,
#  'constant issue': 2,
#  ' blue screen': 2,
#  ' screen death': 2,
#  ' multiple time': 2,
#  ' time phone refuse': 2,
#  ' refuse charge': 2,
#  ' randomly shuts': 2,
#  ' shuts screen': 2,
#  ' phone people': 2,
#  'thanks daughter': 2,
#  'quick refund': 2,
#  'hot use': 2,
#  ' use phone': 2,
#  'battery going percentage': 2,
#  ' store used find': 2,
#  ' failing took software': 2,
#  ' pas apple test': 2,
#  ' failing bad software': 2,
#  'good issue': 2,
#  ' fake plastic': 2,
#  'good condition': 6,
#  'worst working mobile': 2,
#  ' trust seller': 2,
#  ' seller waste money': 2,
#  'new unlocked item': 2,
#  ' charger item': 2,
#  ' new lot': 2,
#  ' brand lot dust': 2,
#  'stated verizon': 2,
#  ' hour minute': 2,
#  ' trying called figure': 2,
#  'satisfied product': 2,
#  ' early perfect loving condition': 2,
#  'fast delivery': 2,
#  ' delivery thank': 2,
#  'month iphone': 2,
#  ' phone carpet': 2,
#  ' carpet feat le protective case': 2,
#  ' case starting reason': 2,
#  ' wire pay': 2,
#  ' fixed buy': 2,
#  'good value': 2,
#  ' value money gift': 2,
#  'happy product': 2,
#  'phone line': 1,
#  ' line goin': 1,
#  'excellent condition': 1,
#  'great phone work': 2,
#  'quick functioning product': 1,
#  'able configure connecting trying working download': 1,
#  ' apple server': 1,
#  ' touch screen': 1,
#  ' mobile repair': 2,
#  ' repair store': 1,
#  ' mobile bougth': 1,
#  ' refurbished new mobile amazon': 1,
#  ' mentioned first frustating experience': 1,
#  ' seller checkednin': 1,
#  ' usd change screen': 1,
#  ' gic problem': 1,
#  'great condition': 3,
#  ' iphone condition work': 1,
#  ' no issue regarding concern': 1,
#  'new put condition': 1,
#  ' phone fine found beware': 1,
#  ' read review': 1,
#  'advertised thank': 1,
#  'good price': 1,
#  ' great mobile': 1,
#  'good buy': 1,
#  'great condition work': 2,
#  'water purchased damage': 1,
#  ' new holding stop': 1,
#  ' liquid indicator': 1,
#  ' based activated serial': 1,
#  'best thing': 1,
#  'perfect little defecto screen': 1,
#  ' resolve problem': 1,
#  'phone iphone': 1,
#  ' enough info': 1,
#  'satisfied great phone': 1,
#  ' recommend seller': 1,
#  'expected accessory': 1,
#  'efficient service': 1,
#  'awesome happy product service': 1,
#  'perfect great seller': 1,
#  'no good iphone camera work': 1,
#  ' d work': 1,
#  ' another phone': 1,
#  'great phone good work': 1,
#  ' beautiful picture': 1,
#  'sealed box': 1,
#  ' apple service': 1,
#  ' phone service center': 1,
#  ' new contacted seller': 1,
#  ' no apple warranty': 1,
#  ' warranty repair': 1,
#  'excellent phone': 1,
#  ' phone needed return': 1,
#  ' old phone': 1,
#  ' past return date': 1,
#  'good excellent condition': 1,
#  'high quality': 1,
#  ' prompt service': 1,
#  ' happy purchase': 1,
#  'samsung couple': 1,
#  ' everyone family': 1,
#  ' used great thing': 1,
#  ' fastest phone': 1,
#  ' several apps': 1,
#  ' thumbprint password': 1,
#  ' password feature': 1,
#  ' miss swipe': 1,
#  ' cool feature swipe typing': 1,
#  ' phone perfect': 1,
#  'phone boyfriend': 1,
#  ' owned excellent condition': 1,
#  'high end': 1,
#  ' end tell': 1,
#  ' good material': 1,
#  ' material seller': 1,
#  ' top notch product': 1,
#  ' unlocked use': 1,
#  'good mark': 1,
#  ' wise phone work': 1,
#  'good shipping product': 1,
#  'nice term': 1,
#  ' term worked mobile network': 1,
#  'new work': 2,
#  ' no complaint arrival': 1,
#  'died month return policy': 1,
#  'bought gifted father': 1,
#  ' local center': 1,
#  ' total treachery': 1,
#  'turn turn charge': 1,
#  'hate thing': 1,
#  ' n thing wife': 1,
#  ' iphone birthday': 1,
#  ' stand use': 1,
#  ' mine home apple': 1,
#  ' intuitive throw thing': 1,
#  ' thing wall': 1,
#  ' star fact': 1,
#  ' mobile wife': 1,
#  ' wife telling tolerates': 1,
#  ' another iphone': 1,
#  'good working condition': 1,
#  'easy transfer': 1,
#  ' transfer data iphone': 1,
#  ' new card phone': 1,
#  'returned item': 1,
#  'matched description': 1,
#  ' described look used iphones': 1,
#  'excellent condition phone': 1,
#  ' no good job': 1,
#  'described unlocked husband': 1,
#  ' old iphones': 1,
#  'new function work': 1,
#  'excellent item': 1,
#  ' new work': 2,
#  'good phone': 1,
#  ' phone overall look': 1,
#  ' no scratch front': 1,
#  ' acceptable price': 1,
#  'fine serve purpose': 1,
#  'next phone amazon': 1,
#  'great experience product': 1,
#  ' good item': 1,
#  ' product excellent seller': 1,
#  ' craigslist letgo': 1,
#  'phone thanx': 1,
#  ' best thanx man': 1,
#  'emailed seller': 1,
#  ' ready use': 1,
#  ' needed turn': 1,
#  ' new scuff top': 1,
#  ' no scratch crack': 1,
#  ' mentioned seller': 1,
#  ' card phone': 1,
#  ' call phone company': 1,
#  ' great seller': 1,
#  ' great product': 2,
#  'seller factory unlock phone': 1,
#  ' unlocked checked apple': 1,
#  ' professional locked': 1,
#  ' no answer': 1,
#  ' unlocked iphone work': 1,
#  ' unlocked phone work': 1,
#  ' work tell beware': 1,
#  ' iphone factory': 1,
#  'great gift': 1,
#  'expected good product': 1,
#  'telephone lot': 1,
#  ' lot scratch screen': 1,
#  'phone networking': 1,
#  ' networking problem': 1,
#  ' problem time network': 1,
#  ' want return': 1,
#  'sealed apple box': 1,
#  ' new odd thing': 1,
#  ' checked apple warranty': 1,
#  ' customer guaranteed service': 1,
#  ' new another small thing': 1,
#  ' language apps': 1,
#  ' many sub menu': 1,
#  ' primary language': 1,
#  ' language english': 1,
#  ' spanish second language': 1,
#  ' chinese sign': 1,
#  'super fast delivery': 1,
#  ' excellent excellent phone': 1,
#  'screw plate': 1,
#  ' plate top': 1,
#  ' lcd connector': 1,
#  ' missing top bad condition': 1,
#  'new condition': 3,
#  ' great hold': 1,
#  ' good charge': 1,
#  ' no using issue': 1,
#  ' tmobile delivery': 1,
#  ' delivery prompt': 1,
#  'defective start waste money': 1,
#  'day earlyer': 1,
#  ' time order': 1,
#  ' order phone brand': 1,
#  ' new original package': 1,
#  'better deal': 1,
#  'fake apple product': 1,
#  'supposed problem payment': 1,
#  ' visa camera': 1,
#  ' work upsetting': 1,
#  'slow many ipads': 1,
#  'good shapthanks': 1,
#  'awesome great condition': 1,
#  ' great buy seller': 1,
#  'great basic design': 1,
#  ' newer model': 1,
#  ' compatible icloud': 1,
#  ' contact icloud': 1,
#  ' apps version app': 1,
#  ' st generation': 1,
#  ' generation iphone itunes': 1,
#  ' want download': 1,
#  ' older compatible version': 1,
#  ' work phone': 2,
#  ' phone course': 1,
#  ' buy condition battery brand': 1,
#  ' new hold day': 1,
#  ' classic phone': 1,
#  'slight damage dayle': 1,
#  ' tear phone': 1,
#  ' big chunk': 1,
#  ' whole bottom corner': 1,
#  ' effected screen charger': 1,
#  ' little smaller dime': 1,
#  ' no charger': 1,
#  ' new charger': 3,
#  ' brand charger charging trouble': 1,
#  ' charger port': 1,
#  'g work': 1,
#  ' basic cool hold': 1,
#  ' right amount': 1,
#  'amazon people': 1,
#  ' good com stuff': 1,
#  ' cheap skeptical': 1,
#  ' shop line': 1,
#  ' debit card': 1,
#  ' amazon com': 1,
#  ' iphone son': 1,
#  ' much need': 1,
#  ' school birthday': 1,
#  ' happy happy thanks': 1,
#  'g work iphone': 1,
#  ' well ring volume': 1,
#  ' sim chip': 1,
#  ' iphone condition': 1,
#  ' condition phone ring': 1,
#  ' better quality control': 1,
#  'jailbreak unlock': 1,
#  ' good phone price': 1,
#  ' every experience': 1,
#  'no compatible verizon': 1,
#  ' old way': 1,
#  'great work': 1,
#  ' looking frozen start screen': 1,
#  ' subsidiary warehouse': 1,
#  ' placed order warehouse deal warehouse': 1,
#  ' warehouse deal inventory': 1,
#  ' unable replace order': 1,
#  ' printer print return': 1,
#  ' return label': 1,
#  ' bussiness day': 1,
#  ' day money': 1,
#  'new condition problem': 1,
#  ' outdated iphone': 1,
#  ' newest generation': 1,
#  ' good bargain': 1,
#  'plugged charger': 1,
#  ' current charge iphone': 1,
#  ' dead phone': 1,
#  ' iphone box': 1,
#  ' signed year': 1,
#  ' year contract': 1,
#  ' new contract time': 1,
#  ' mess phone light': 1,
#  ' light scratch': 1,
#  'disappointed phone': 1,
#  'gift work': 1,
#  ' work return': 1,
#  ' pasted day': 1,
#  ' day policy lesson': 1,
#  'water damage': 1,
#  'broken thought': 1,
#  ' good condition': 3,
#  ' phone charger': 1,
#  ' different seller': 1,
#  'no internet': 1,
#  ' no apps': 1,
#  'phone use': 1,
#  ' durable phone grandson': 1,
#  'cost money': 1,
#  ' unlocked money speaker': 1,
#  'liked iphone place': 1,
#  ' music download': 1,
#  ' download apps': 2,
#  'advertised function': 1,
#  ' basic phone': 1,
#  ' camera surf': 1,
#  ' simple used surf web': 1,
#  'able unlocked verizon': 1,
#  ' complete waste money': 1,
#  'new phone': 1,
#  'shipping iphone': 1,
#  ' great condition': 3,
#  ' volume button': 1,
#  ' missing button crack': 1,
#  'cell phone': 1,
#  ' nervous buying condition love': 1,
#  'itthe cheap useablei': 1,
#  'worst bought thing': 1,
#  ' broke month': 1,
#  ' lit fire': 1,
#  'pay shop fix': 1,
#  ' bad phone': 1,
#  ' see problem': 1,
#  ' missing screw': 1,
#  ' assembled mute button': 1,
#  'good condition screen': 1,
#  ' perfect thing': 1,
#  ' unlock use': 1,
#  ' use sim card': 1,
#  ' extra fee unlock': 1,
#  'waste money': 1,
#  ' huge money selling shame': 1,
#  ' unusable ripping': 1,
#  'operating system': 1,
#  ' system apps': 1,
#  ' grocery store': 1,
#  ' local store weather channel': 1,
#  ' older apps': 1,
#  'rate item': 1,
#  'used defective iphone': 1,
#  ' description contacted monsterbuyback': 1,
#  ' speedy return': 1,
#  ' cooperative apologized great company': 1,
#  ' reputable trustworthy thanks': 1,
#  'great shape': 1,
#  ' great devilery': 1,
#  'good precio envio servicio empaque': 1,
#  ' grande peque buena': 1,
#  ' buena comunicacion': 1,
#  'good amazon': 1,
#  ' no problem product': 1,
#  ' seller godblessxoxo': 1,
#  'phone friend': 1,
#  ' terrible scratch': 1,
#  ' many different company': 1,
#  'great use': 1,
#  ' product word': 1,
#  ' overall satisfied word place telling holder': 1,
#  'phone calling work': 1,
#  ' feature camera': 1,
#  ' camera web': 1,
#  ' emergency purpose': 1,
#  ' ok phone': 1,
#  ' feature use': 1,
#  ' use car': 1,
#  'prepaid att service': 1,
#  'second phone': 1,
#  ' unlocked returned expense': 1,
#  ' sure order': 1,
#  ' happy box': 1,
#  ' unlocked order': 1,
#  ' send want': 1,
#  'phone feature': 1,
#  ' feature price': 1,
#  ' comfortable recommending fact': 1,
#  ' friend moment': 1,
#  ' moment thing': 1,
#  ' locked thought': 1,
#  ' complete review': 1,
#  ' video store': 1,
#  ' store telephone number': 1,
#  'best phone': 1,
#  ' good value price': 1,
#  'new cell': 1,
#  ' multiple registration number': 1,
#  ' refunded whole thing': 1,
#  ' many problem': 2,
#  'phone point': 1,
#  ' point apps': 1,
#  ' old old phone': 1,
#  ' newer version wtf': 1,
#  'research buying': 1,
#  ' upgradeable grandson day': 1,
#  ' day thing': 1,
#  'decent shape owner': 1,
#  ' old otterbox': 1,
#  ' charged unplugged charger': 1,
#  ' unusable school': 1,
#  ' net prepaid held learned phone': 1,
#  ' guess lesson': 1,
#  ' used iphones': 1,
#  ' terrible amazon': 1,
#  ' product defectiveness': 1,
#  ' used defectiveness shipment': 1,
#  'open program': 1,
#  ' program running background': 1,
#  'puchase vintage': 1,
#  ' happy vintage fun phone': 1,
#  'nice item': 1,
#  ' nice item': 1,
#  ' expected item gift': 1,
#  'no belief': 1,
#  ' new good condition': 1,
#  'no apps': 1,
#  'damaging telefonolo': 1,
#  ' phone fraud': 1,
#  'phone activate': 1,
#  'call horrible phone': 1,
#  'good new product publication': 1,
#  'described work': 1,
#  ' pleased purchase thank': 1,
#  'piece screen': 1,
#  ' total disaster': 1,
#  ' sell phone': 1,
#  ' satisfied purchase': 1,
#  ' honest supplierhowever': 1,
#  ' supplierhowever know': 1,
#  ' supplier messed purchased used thing': 1,
#  ' apple phone': 1,
#  ' card slot': 1,
#  ' great slot internet work': 1,
#  'star item': 1,
#  ' described seller': 1,
#  ' every one': 1,
#  'great love': 1,
#  ' form u': 1,
#  'phone great condition': 1,
#  ' star rating': 2,
#  ' phone apps': 1,
#  ' disabled upgrade': 1,
#  ' application phone': 1,
#  ' good calling texting': 1,
#  ' searching web': 1,
#  ' great deal': 1,
#  'worst iphone': 1,
#  ' phone paperweight': 1,
#  ' paperweight phone': 1,
#  ' apps phone': 1,
#  ' major apps': 1,
#  ' facebook twitter': 1,
#  ' fourth apps': 1,
#  ' took day': 1,
#  ' searching apps': 1,
#  ' internet phone': 1,
#  ' phone static': 1,
#  ' static sound': 1,
#  ' phone call': 2,
#  ' slow long load': 1,
#  ' faster phone problem': 1,
#  ' cheap problem phone': 1,
#  ' weird clicking noise unlock phone phone': 1,
#  ' another account': 1,
#  ' download music': 1,
#  ' music erase': 1,
#  ' tried erase phone start': 1,
#  ' app store': 1,
#  ' another email': 1,
#  ' wanted phone': 1,
#  ' contact seller': 1,
#  ' seller return phone': 1,
#  ' going reply': 1,
#  ' reset setting turn': 1,
#  ' phone advice': 1,
#  ' advice purchase': 1,
#  ' back purchase iphone': 1,
#  ' higher money': 1,
#  ' samsung phone': 1,
#  ' good ipod player': 1,
#  ' good good digital picture frame': 1,
#  ' child game': 1,
#  ' actual phone': 1,
#  ' phone stay': 1,
#  'time trip': 1,
#  ' costed extra unlocked unit': 1,
#  ' no big thought deal': 1,
#  ' description thank': 1,
#  'perfect used item': 1,
#  ' r firmware': 1,
#  ' firmware work': 1,
#  ' described whited excellent thank': 1,
#  'new apps': 1,
#  ' backup phone music': 1,
#  ' basic music player': 1,
#  'lit ringer button move': 1,
#  ' phone condition problem': 1,
#  ' much getting problem': 1,
#  'phone sim card': 1,
#  ' card tray': 1,
#  ' another sim tray': 1,
#  ' pay store': 1,
#  ' tray store fix waste money': 1,
#  ' money scam': 1,
#  'sensitive phone': 1,
#  ' unintended contact phone': 1,
#  ' outstanding meet expectation': 1,
#  'expected lot': 1,
#  'fantastic condition problem': 1,
#  ' problem miss iphone': 1,
#  ' old support apps': 1,
#  ' excellent product': 1,
#  ' product work': 1,
#  ' ammended product': 1,
#  'known apple': 1,
#  ' no apps software': 1,
#  ' money useless device': 1,
#  'fine week': 1,
#  ' week turn': 1,
#  ' battery point': 1,
#  ' new iphone': 1,
#  'unlock phone': 1,
#  ' unlocked son': 1,
#  'turned perfect gift': 1,
#  ' expected work': 1,
#  'visible front clean delivery': 1,
#  ' perfect good price': 1,
#  ' unlock dealer': 1,
#  'brand new granddaughter': 1,
#  'old iphone': 1,
#  ' care move': 1,
#  'tried charge': 1,
#  'incorrect product customer service': 1,
#  ' blemish programming': 1,
#  ' no scratch programming work': 1,
#  ' complaint menu': 1,
#  ' crisp press': 1,
#  ' press feel': 1,
#  'opened box': 1,
#  ' charged battery': 1,
#  ' latest running software': 1,
#  ' perfect gift': 1,
#  ' smart phone g': 1,
#  ' great hand': 1,
#  'free charger': 1,
#  ' new angry item': 1,
#  'love seller': 1,
#  ' cheap bet thing': 1,
#  ' thing factory': 1,
#  ' untethered jailbreak io': 1,
#  ' cable charger': 1,
#  'look new freeze': 1,
#  'no surprise work function': 1,
#  'several seller': 1,
#  ' unlocked seller selling': 1,
#  ' different card work': 1,
#  'phone unlocked trusting': 1,
#  ' invalid sim message': 1,
#  ' red battery': 1,
#  ' battery line': 1,
#  ' line show': 1,
#  ' worse dead show screen': 1,
#  ' phone trip': 1,
#  'box ringer': 1,
#  ' mute switch': 1,
#  ' switch work': 1,
#  ' ringer work seller': 1,
#  ' dy battery': 1,
#  ' find phone battery seller': 1,
#  ' mine sound': 1,
#  ' broken mute ringer': 1,
#  ' indifferent ringer able switch': 1,
#  ' unusable phone': 1,
#  ' ask lot': 1,
#  ' careful lot question': 1,
#  ' trusted seller': 1,
#  ' condition butit': 1,
#  ' new battery thebattery': 1,
#  ' battery work': 1,
#  ' pay dollarsworth work': 1,
#  ' half refund': 1,
#  'gift son': 1,
#  ' loved moment': 1,
#  ' college class': 1,
#  ' class cincinnati': 1,
#  ' touch family': 1,
#  ' family friend': 1,
#  ' apple product': 2,
#  ' downloaded music': 1,
#  ' new apple iphone': 1,
#  ' enought space': 1,
#  ' nice library music': 1,
#  'french carrier': 1,
#  ' water spot': 1,
#  ' unlocked locked carrier spot screen': 1,
#  'serial number box': 1,
#  ' serial number thephone': 1,
#  ' thephone ear phone': 1,
#  ' manufactured returned product': 1,
#  'good phone big given gb': 1,
#  ' running io': 1,
#  'great supposed condition': 1,
#  ' ad item': 1,
#  ' item part': 1,
#  ' customer service': 1,
#  ' service adjustment': 1,
#  ' part adjustment amazon': 1,
#  ' expected due earlier order problem': 1,
#  'disappointing product': 1,
#  ' big crack': 1,
#  'white phone': 1,
#  ' waiting answer': 1,
#  'useless drawer': 1,
#  'unlocked received phone': 1,
#  ' card phone work': 1,
#  ' u unlock phone': 1,
#  ' download application phone': 1,
#  ' update phone': 1,
#  ' unlock phone': 1,
#  ' pay contacted seller': 1,
#  ' refund initial spent dollar': 1,
#  ' refund money': 1,
#  ' email fact': 1,
#  ' fact phone': 1,
#  ' locked pay': 1,
#  ' no happy shopping seller': 1,
#  'scratch dent': 1,
#  ' no dent phone look': 1,
#  ' unlocked baseband': 1,
#  ' much trouble': 1,
#  ' great purchase': 1,
#  'ipod size': 1,
#  ' good support': 1,
#  ' newest good apps': 1,
#  'old school shape': 1,
#  ' solid buy': 1,
#  'good incomplete condition': 1,
#  ' miss accessory doubt': 1,
#  ' additional spending': 1,
#  'missing switch cover': 1,
#  ' otter box cover': 1,
#  ' cover thing': 1,
#  ' place phone look': 1,
#  ' look work': 1,
#  ' disappointed missing part': 1,
#  'phone son': 1,
#  ' first great price item': 1,
#  'description iphone': 1,
#  ' water damage': 1,
#  ' latter battery': 1,
#  ' internal part': 1,
#  ' braking front glass': 1,
#  'fooled item description': 1,
#  ' broken innocent buyer': 1,
#  'phone screen': 1,
#  'good purchase': 1,
#  ' battery delievred item': 1,
#  ' big issue': 1,
#  ' issue batter': 1,
#  ' battery life': 1,
#  ' life phone': 1,
#  ' listened music': 1,
#  ' texting somehimes': 1,
#  ' somehimes battery': 1,
#  ' call cell phone': 1,
#  ' many time': 1,
#  ' defeat purpose': 1,
#  ' purpose phone': 1,
#  ' cell phone': 1,
#  ' ask seller': 1,
#  ' used seller battery end': 1,
#  ' returned phone quick refund': 1,
#  'price condition': 1,
#  ' visible scratch screen': 1,
#  ' cosmetic phone work': 1,
#  ' cosmetic i d recomend': 1,
#  ' amazon warehouse': 1,
#  ' little money': 1}

# %%
unique_keywords = freq_count.keys()
unique_keywords
# Out:
# dict_keys(['phone look', ' no scratch', ' scratch shipping', ' arrived time', ' great unlocked work', ' perfect mexican carrier', ' sure using problem', ' u mobile', 'shipped fast excited son', ' great condition phone', ' money thanks', ' fast shipping', 'pleased great working affordable shape', 'verizon phone', ' verizon sim card', ' cell service', ' serial number', ' agian phone', 'verizon account', ' huge waste time', ' time money', 'nice phone paid price', ' sent review', 'gizmo trader', ' scratch good company', ' described better product', 'button mess', ' mess lot', 'great seller', ' work version', ' many version problem', 'apple product', ' product rep verizon store', ' phone verizon', ' verizon system', ' closer inspection', ' home button', ' correct center', ' center body phone', ' dealing phone process', ' refund purchase', ' different supplier', 'great minor scratch', ' fine battery short life', ' daily overall good major problem charger', ' phone work', ' free second one', ' old charger', 'advertised apple iphone', ' store insert sim card', ' card work', ' no complaint', 'phone type', ' type freeze', 'fast shipping phone look', 'great product', 'ready connected updated month', ' phone screen', ' no touch screen', ' obvious recieved replaced screen', 'month phone earpiece', ' worked earpiece work', 'disappointed speaker work', 'home button', ' button working mind', 'iphone manner phone work', 'phone perfect', 'no received trouble', 'first phone', ' original box', ' new shipped device', ' either charger', ' neither phone', ' original accessory', ' charger replacement', ' plugged pop', ' original correct charger', ' nothing phone', ' purchasing seller', 'phone thankyiu', 'purchased unit gift', ' warranty replacement', ' blue original seller', ' pink put iphone', ' blue cover', ' cover apple perspective', ' void warranty', ' warranty lesson', ' phone seller', 'advertised excellent condition', ' scratch screen', ' screen pop', ' fake mispelled word', ' disappointed product', 'spankin lightning loose port', ' replacement stat', 'received phone', 'messed glitch count', 'phone work', ' fine charger', 'exceeded expectation', 'good charge', 'fast work', 'great good item including description', ' photo purchased kudos', ' great work', 'good work', ' iphone flawless', 'looked work', ' refurbished phone seller', ' answered question', 'much service', ' phone service excellent', ' new product', ' excellent price', ' love go carrier', ' another party cost', ' excellent friend', ' monthly friend family member', ' direct putting thank', ' much amazon', ' big smile', 'great exterior condition screen', ' pink line', 'extra charging malfunction', ' charging use', ' much tape case', ' happy phone', 'great great condition', ' great ordering experience', ' new phone thank', 'tact phone', ' apple logo screen', ' option hardware', ' hardware problem', ' exhausted problem phone', ' turned disappointing high hope', ' test luck', 'phone place', ' green silicone', ' second iphone phone', 'small working issue', ' p button', ' cost beat', 'new little iphone apple', ' bad program', ' itunes account', ' get apps', 'replacement son', ' son phone', ' getting issue', ' set phone fault', ' new sim card', ' broke store', ' price replacement', ' thrilled full replacement phone', ' face time', ' time friend', 'super fast shipping', 'wifi device', ' month purchase', 'phone couple', ' apple store', 'great looking working', ' specific seller', ' seller review', 'whole day', ' day power button', ' button faulty', 'love phone', ' verizon phone', ' customer rep phone', ' long time', ' verizon customer', ' time customer year', ' t service', ' big mistake', ' long negative story', ' verizon iphone', ' verizon charge', ' charge month', ' new service', ' stupid lied refuse', ' verizon type', 'c gb storage', ' ordered phone', ' no problem', ' plenty good deal price', 'needed phone', 'verizon network', 'failed recharging repairable purchase', ' new phone', ' phone ap ...

# %%
clustures = []

used_keywords = []

for i in tqdm(unique_keywords):
    current_custer = [i]
    
    if (i in used_keywords):
        continue
    
    used_keywords.append(i)
    
    
    for j in unique_keywords:
        if  (j in used_keywords):
            continue
    
        current_score = similarity_calc(i,j)
        if current_score>0.7:
            current_custer.append(j)
            used_keywords.append(j)
            
    
    clustures.append(current_custer)
        
#     break
# Out:
# 100%|███████████████████████████████████████| 993/993 [1:27:40<00:00,  5.30s/it]

# %%
len(clustures)
# Out:
# 571

# %%
clustures[:10]
# Out:
# [['phone look',
#   ' agian phone',
#   ' phone verizon',
#   ' phone work',
#   'phone type',
#   ' phone screen',
#   'first phone',
#   'received phone',
#   'phone work',
#   'phone place',
#   'needed phone',
#   ' phone people',
#   ' use phone',
#   'phone line',
#   ' another phone',
#   'good phone',
#   ' phone overall look',
#   'phone use',
#   ' basic phone',
#   'cell phone',
#   ' ok phone',
#   'second phone',
#   'phone feature',
#   ' phone apps',
#   ' application phone',
#   ' apps phone',
#   ' internet phone',
#   ' wanted phone',
#   ' actual phone',
#   ' phone trip',
#   ' place phone look',
#   'phone screen',
#   ' call cell phone',
#   ' purpose phone',
#   ' cell phone'],
#  [' no scratch',
#   'great minor scratch',
#   'scratch work',
#   ' no scrape',
#   ' no scratch front',
#   ' no scratch crack',
#   ' terrible scratch',
#   ' no scratch programming work'],
#  [' scratch shipping'],
#  [' arrived time', ' time order', 'time trip'],
#  [' great unlocked work', ' great work', 'great work'],
#  [' perfect mexican carrier'],
#  [' sure using problem'],
#  [' u mobile',
#   'verizon phone',
#   ' verizon phone',
#   ' mobile bougth',
#   ' great mobile'],
#  ['shipped fast excited son'],
#  [' great condition phone',
#   'phone perfect',
#   ' phone service excellent',
#   ' happy phone',
#   ' thrilled full replacement phone',
#   ' ordered phone',
#   ' phone superb',
#   ' phone excellent made condition',
#   'awesome phone mine',
#   'awesome phone',
#   'great phone work',
#   'satisfied great phone',
#   'great phone good work',
#   'excellent phone',
#   ' phone perfect',
#   'excellent condition phone',
#   ' excellent excellent phone',
#   ' condition phone ring',
#   ' good phone price',
#   ' bad phone',
#   'best phone',
#   'phone great condition',
#   ' cheap problem phone',
#   ' phone condition problem',
#   'good phone big given gb']]

# %%
final_result = []
for cp in clustures:
    cluster_key_count = {}
    for key_c in cp:
        cluster_key_count[key_c] = freq_count[key_c]
    
    items = []
    for i in list(tuple(cluster_key_count.keys())):
        items.append(i.split()[0])
    dict1 = {}
    for item in items:
        if not item in dict1:
            dict1[item] = items.count(item)
    dict1 = sorted(dict1.keys(), reverse=True)[0]

    curr_cul_keys = list(cluster_key_count.keys())
    curr_cul_values = list(cluster_key_count.values())
    sum_of_similar_words = np.sum(curr_cul_values)
    highest_count_key = curr_cul_keys[np.argmax(curr_cul_values)]
    highest_count_value = np.max(curr_cul_values)
    final_result.append([cluster_key_count,sum_of_similar_words,highest_count_key,len(cluster_key_count), dict1])
    
#     break

# %%
final_result
# Out:
# [[{'phone look': 1,
#    ' agian phone': 1,
#    ' phone verizon': 1,
#    ' phone work': 2,
#    'phone type': 1,
#    ' phone screen': 4,
#    'first phone': 1,
#    'received phone': 1,
#    'phone work': 4,
#    'phone place': 1,
#    'needed phone': 1,
#    ' phone people': 2,
#    ' use phone': 2,
#    'phone line': 1,
#    ' another phone': 1,
#    'good phone': 1,
#    ' phone overall look': 1,
#    'phone use': 1,
#    ' basic phone': 1,
#    'cell phone': 1,
#    ' ok phone': 1,
#    'second phone': 1,
#    'phone feature': 1,
#    ' phone apps': 1,
#    ' application phone': 1,
#    ' apps phone': 1,
#    ' internet phone': 1,
#    ' wanted phone': 1,
#    ' actual phone': 1,
#    ' phone trip': 1,
#    ' place phone look': 1,
#    'phone screen': 1,
#    ' call cell phone': 1,
#    ' purpose phone': 1,
#    ' cell phone': 1},
#   44,
#   ' phone screen',
#   35,
#   'wanted'],
#  [{' no scratch': 4,
#    'great minor scratch': 1,
#    'scratch work': 1,
#    ' no scrape': 2,
#    ' no scratch front': 1,
#    ' no scratch crack': 1,
#    ' terrible scratch': 1,
#    ' no scratch programming work': 1},
#   12,
#   ' no scratch',
#   8,
#   'terrible'],
#  [{' scratch shipping': 1}, 1, ' scratch shipping', 1, 'scratch'],
#  [{' arrived time': 1, ' time order': 1, 'time trip': 1},
#   3,
#   ' arrived time',
#   3,
#   'time'],
#  [{' great unlocked work': 1, ' great work': 1, 'great work': 1},
#   3,
#   ' great unlocked work',
#   3,
#   'great'],
#  [{' perfect mexican carrier': 1},
#   1,
#   ' perfect mexican carrier',
#   1,
#   'perfect'],
#  [{' sure using problem': 1}, 1, ' sure using problem', 1, 'sure'],
#  [{' u mobile': 1,
#    'verizon phone': 1,
#    ' verizon phone': 2,
#    ' mobile bougth': 1,
#    ' great mobile': 1},
#   6,
#   ' verizon phone',
#   5,
#   'verizon'],
#  [{'shipped fast excited son': 1},
#   1,
#   'shipped fast excited son',
#   1,
#   'shipped'],
#  [{' great condition phone': 1,
#    'phone perfect': 1,
#    ' phone service excellent': 1,
#    ' happy phone': 1,
#    ' thrilled full replacement phone': 1,
#    ' ordered phone': 1,
#    ' phone superb': 1,
#    ' phone excellent made condition': 1,
#    'awesome phone mine': 2,
#    'awesome phone': 2,
#    'great phone work': 2,
#    'satisfied great phone': 1,
#    'great phone good work': 1,
#    'excellent phone': 1,
#    ' phone perfect': 1,
#    'excellent condition phone': 1,
#    ' excellent excellent phone': 1,
#    ' condition phone ring': 1,
#    ' good phone price': 1,
#    ' bad phone': 1,
#    'best phone': 1,
#    'phone great condition': 1,
#    ' cheap problem phone': 1,
#    ' phone condition problem': 1,
#    'good phone big given gb': 1},
#   28,
#   'awesome phone mine',
#   25,
#   'thrilled'],
#  [{' money thanks': 1, ' value money gift': 2, 'cost money': 1},
#   4,
#   ' value money gift',
#   3,
#   'value'],
#  [{' fast shipping': 1,
#    'super fast shipping': 1,
#    ' fast shipping work': 1,
#    ' new speedy shipping': 2,
#    'fast delivery': 2,
#    'good shipping product': 1,
#    'super fast delivery': 1},
#   9,
#   ' new speedy shipping',
#   7,
#   'super'],
#  [{'pleased great working affordable shape': 1, 'great looking working': 1},
#   2,
#   'pleased great working affordable shape',
#   2,
#   'pleased'],
#  [{' verizon sim card': 1,
#    ' store insert sim card': 1,
#    ' new sim card': 1,
#    ' sim card': 10,
#    'no sim card': 2,
#    ' card phone': 1,
#    ' use sim card': 1,
#    'phone sim card': 1},
#   18,
#   ' sim card',
#   8,
#   'verizon'],
#  [{' cell service': 1, ' phone service center': 1},
#   2,
#   ' cell service',
#   2,
#   'phone'],
#  [{' serial number': 1, 'serial number box': 1, ' serial number thephone': 1},
#   3,
#   ' serial number',
#   3,
#   'serial'],
#  [{'verizon account': 1,
#    ' verizon system': 1,
#    ' itunes account': 1,
#    ' verizon customer': 1},
#   4,
#   'verizon account',
#   4,
#   'verizon'],
#  [{' huge waste time': 1,
#    'waste time': 2,
#    ' complete waste money': 1,
#    'waste money': 1},
#   5,
#   'waste time',
#   4,
#   'waste'],
#  [{' time money': 1, ' time customer year': 1, ' day money': 1},
#   3,
#   ' time money',
#   3,
#   'time'],
#  [{'nice phone paid price': 1, ' sell phone': 1},
#   2,
#   'nice phone paid price',
#   2,
#   'sell'],
#  [{' sent review': 1, ' read review': 1, ' complete review': 1},
#   3,
#   ' sent review',
#   3,
#   'sent'],
#  [{'gizmo trader': 1}, 1, 'gizmo trader', 1, 'gizmo'],
#  [{' scratch good company': 1}, 1, ' scratch good company', 1, 'scratch'],
#  [{' described better product': 1,
#    'great product': 1,
#    ' great product': 2,
#    ' product word': 1,
#    ' excellent product': 1,
#    ' product work': 1,
#    ' ammended product': 1},
#   8,
#   ' great product',
#   7,
#   'product'],
#  [{'button mess': 1, ' button faulty': 1, ' missing button crack': 1},
#   3,
#   'button mess',
#   3,
#   'missing'],
#  [{' mess lot': 1, ' much trouble': 1}, 2, ' mess lot', 2, 'much'],
#  [{'great seller': 1,
#    ' excellent price': 1,
#    ' specific seller': 1,
#    ' seller review': 1,
#    'great price': 1,
#    ' use seller': 1,
#    'seller service': 1,
#    ' great seller brand': 2,
#    'good buy': 1,
#    ' recommend seller': 1,
#    'perfect great seller': 1,
#    ' material seller': 1,
#    ' product excellent seller': 1,
#    ' mentioned seller': 1,
#    ' great seller': 1,
#    ' great buy seller': 1,
#    ' different seller': 1,
#    ' described seller': 1,
#    'several seller': 1,
#    ' great purchase': 1,
#    'good purchase': 1},
#   22,
#   ' great seller brand',
#   21,
#   'use'],
#  [{' work version': 1}, 1, ' work version', 1, 'work'],
#  [{' many version problem': 1}, 1, ' many version problem', 1, 'many'],
#  [{'apple product': 1,
#    'advertised apple iphone': 1,
#    ' cover apple perspective': 1,
#    ' apple logo screen': 1,
#    'new little iphone apple': 1,
#    ' apple store': 5,
#    ' phone apple': 1,
#    ' apple ver': 1,
#    ' apple iphone': 1,
#    ' apple icon': 1,
#    ' pas apple test': 2,
#    ' apple server': 1,
#    ' apple service': 1,
#    'fake apple product': 1,
#    ' apple phone': 1,
#    'known apple': 1,
#    ' apple product': 2,
#    ' new apple iphone': 1},
#   24,
#   ' apple store',
#   18,
#   'phone'],
#  [{' product rep verizon store': 1, ' product world seller': 2},
#   3,
#   ' product world seller',
#   2,
#   'product'],
#  [{' closer inspection': 1}, 1, ' closer inspection', 1, 'closer'],
#  [{' home button': 1, 'home button': 1}, 2, ' home button', 2, 'home'],
#  [{' correct center': 1, ' local center': 1},
#   2,
#   ' correct center',
#   2,
#   'local'],
#  [{' center body phone': 1}, 1, ' center body phone', 1, 'center'],
#  [{' dealing phone process': 1,
#    ' wise phone work': 1,
#    ' call phone company': 1,
#    'phone networking': 1,
#    'phone calling work': 1},
#   5,
#   ' dealing phone process',
#   5,
#   'wise'],
#  [{' refund purchase': 1,
#    ' returned seller refund': 1,
#    ' paid return seller': 2,
#    'quick refund': 2,
#    ' refunded whole thing': 1,
#    ' half refund': 1,
#    ' refund initial spent dollar': 1,
#    ' refund money': 1,
#    ' returned phone quick refund': 1},
#   11,
#   ' paid return seller',
#   9,
#   'returned'],
#  [{' different supplier': 1, ' supplierhowever know': 1},
#   2,
#   ' different supplier',
#   2,
#   'supplierhowever'],
#  [{' fine battery short life': 1,
#    ' bad battery': 2,
#    ' worse battery life': 2,
#    ' new battery thebattery': 1,
#    ' battery work': 1,
#    ' latter battery': 1,
#    ' battery life': 1},
#   9,
#   ' bad battery',
#   7,
#   'worse'],
#  [{' daily overall good major problem charger': 1, ' fine charger': 1},
#   2,
#   ' daily overall good major problem charger',
#   2,
#   'fine'],
#  [{' free second one': 1}, 1, ' free second one', 1, 'free'],
#  [{' old charger': 1,
#    ' either charger': 1,
#    ' charger replacement': 1,
#    ' original correct charger': 1,
#    ' knew orginal charger': 2,
#    ' last long charger': 2,
#    ' new charger charger reason': 2,
#    ' charger item': 2,
#    ' no charger': 1,
#    ' new charger': 3,
#    'plugged charger': 1,
#    ' charged unplugged charger': 1},
#   18,
#   ' new charger',
#   12,
#   'plugged'],
#  [{' card work': 2,
#    ' card slot': 1,
#    ' card tray': 1,
#    ' different card work': 1,
#    ' card phone work': 1},
#   6,
#   ' card work',
#   5,
#   'different'],
#  [{' no complaint': 3,
#    'no received trouble': 1,
#    ' no problem': 3,
#    ' no issue regarding concern': 1,
#    ' no complaint arrival': 1},
#   9,
#   ' no complaint',
#   5,
#   'no'],
#  [{' type freeze': 1}, 1, ' type freeze', 1, 'type'],
#  [{'fast shipping phone look': 1}, 1, 'fast shipping phone look', 1, 'fast'],
#  [{'ready connected updated month': 1},
#   1,
#   'ready connected updated month',
#   1,
#   'ready'],
#  [{' no touch screen': 1, ' touch screen': 1},
#   2,
#   ' no touch screen',
#   2,
#   'touch'],
#  [{' obvious recieved replaced screen': 1},
#   1,
#   ' obvious recieved replaced screen',
#   1,
#   'obvious'],
#  [{'month phone earpiece': 1, ' month ear piece': 1, ' thephone ear phone': 1},
#   3,
#   'month phone earpiece',
#   3,
#   'thephone'],
#  [{' worked earpiece work': 1}, 1, ' worked earpiece work', 1, 'worked'],
#  [{'disappointed speaker work': 1},
#   1,
#   'disappointed speaker work',
#   1,
#   'disappointed'],
#  [{' button working mind': 1}, 1, ' button working mind', 1, 'button'],
#  [{'iphone manner phone work': 1,
#    ' second iphone phone': 1,
#    ' verizon iphone': 1,
#    ' iphone condition work': 1,
#    'phone iphone': 1,
#    ' described look used iphones': 1,
#    ' iphone condition': 1,
#    'used defective iphone': 1,
#    ' used iphones': 1},
#   9,
#   'iphone manner phone work',
#   9,
#   'verizon'],
#  [{' original box': 2, 'opened box': 1}, 3, ' original box', 2, 'original'],
#  [{' new shipped device': 1}, 1, ' new shipped device', 1, 'new'],
#  [{' neither phone': 1, ' nothing phone': 1},
#   2,
#   ' neither phone',
#   2,
#   'nothing'],
#  [{' original accessory': 1, 'expected accessory': 1},
#   2,
#   ' original accessory',
#   2,
#   'original'],
#  [{' plugged pop': 1}, 1, ' plugged pop', 1, 'plugged'],
#  [{' purchasing seller': 1,
#    'purchasing experience': 2,
#    ' seller waste money': 2,
#    ' seller checkednin': 1,
#    ' new contacted seller': 1,
#    ' contact seller': 1,
#    ' unlocked seller selling': 1,
#    ' pay contacted seller': 1,
#    ' ask seller': 1},
#   11,
#   'purchasing experience',
#   9,
#   'unlocked'],
#  [{'phone thankyiu': 1,
#    ' new phone thank': 1,
#    'phone thank': 1,
#    ' telephone company': 2,
#    'phone friend': 1,
#    'phone point': 1,
#    ' phone call': 2},
#   9,
#   ' telephone company',
#   7,
#   'telephone'],
#  [{'purchased unit gift': 1, ' expected item gift': 1},
#   2,
#   'purchased unit gift',
#   2,
#   'purchased'],
#  [{' warranty replacement': 1, ' void warranty': 1, ' warranty repair': 1},
#   3,
#   ' warranty replacement',
#   3,
#   'warranty'],
#  [{' blue original seller': 1, ' blue cover': 1},
#   2,
#   ' blue original seller',
#   2,
#   'blue'],
#  [{' pink put iphone': 1}, 1, ' pink put iphone', 1, 'pink'],
#  [{' warranty lesson': 1}, 1, ' warranty lesson', 1, 'warranty'],
#  [{' phone seller': 1,
#    ' refurbished phone seller': 1,
#    'seller factory unlock phone': 1,
#    ' order phone brand': 1,
#    ' seller return phone': 1,
#    ' find phone battery seller': 1},
#   6,
#   ' phone seller',
#   6,
#   'seller'],
#  [{'advertised excellent condition': 1,
#    'good condition': 6,
#    'excellent condition': 1,
#    'great condition': 3,
#    'good excellent condition': 1,
#    'high quality': 1,
#    ' owned excellent condition': 1,
#    'excellent item': 1,
#    'awesome great condition': 1,
#    ' good condition': 3,
#    ' great condition': 3},
#   22,
#   'good condition',
#   11,
#   'owned'],
#  [{' scratch screen': 1,
#    ' lot scratch screen': 1,
#    ' visible scratch screen': 1},
#   3,
#   ' scratch screen',
#   3,
#   'visible'],
#  [{' screen pop': 1}, 1, ' screen pop', 1, 'screen'],
#  [{' fake mispelled word': 1}, 1, ' fake mispelled word', 1, 'fake'],
#  [{' disappointed product': 1, 'disappointing product': 1},
#   2,
#   ' disappointed product',
#   2,
#   'disappointing'],
#  [{'spankin lightning loose port': 1},
#   1,
#   'spankin lightning loose port',
#   1,
#   'spankin'],
#  [{' replacement stat': 1}, 1, ' replacement stat', 1, 'replacement'],
#  [{'messed glitch count': 1}, 1, 'messed glitch count', 1, 'messed'],
#  [{'exceeded expectation': 1}, 1, 'exceeded expectation', 1, 'exceeded'],
#  [{'good charge': 1, ' con charger': 2, ' good charge': 1},
#   4,
#   ' con charger',
#   3,
#   'good'],
#  [{'fast work': 1}, 1, 'fast work', 1, 'fast'],
#  [{'great good item including description': 1,
#    ' good material': 1,
#    ' good item': 1,
#    'nice item': 1,
#    ' nice item': 1},
#   5,
#   'great good item including description',
#   5,
#   'nice'],
#  [{' photo purchased kudos': 1}, 1, ' photo purchased kudos', 1, 'photo'],
#  [{'good work': 1,
#    'looked work': 1,
#    'great condition work': 2,
#    'good mark': 1,
#    'new work': 2,
#    'good working condition': 1,
#    ' new work': 2,
#    ' grande peque buena': 1,
#    'described work': 1},
#   12,
#   'great condition work',
#   9,
#   'new'],
#  [{' iphone flawless': 1}, 1, ' iphone flawless', 1, 'iphone'],
#  [{' answered question': 1}, 1, ' answered question', 1, 'answered'],
#  [{'much service': 1,
#    'service product': 2,
#    'efficient service': 1,
#    'good precio envio servicio empaque': 1,
#    ' customer service': 1},
#   6,
#   'service product',
#   5,
#   'service'],
#  [{' new product': 2, 'good new product publication': 1},
#   3,
#   ' new product',
#   2,
#   'new'],
#  [{' love go carrier': 1}, 1, ' love go carrier', 1, 'love'],
#  [{' another party cost': 1}, 1, ' another party cost', 1, 'another'],
#  [{' excellent friend': 1, ' friend moment': 1},
#   2,
#   ' excellent friend',
#   2,
#   'friend'],
#  [{' monthly friend family member': 1, ' family friend': 1},
#   2,
#   ' monthly friend family member',
#   2,
#   'monthly'],
#  [{' direct putting thank': 1, 'advertised thank': 1},
#   2,
#   ' direct putting thank',
#   2,
#   'direct'],
#  [{' much amazon': 1,
#    'amazon people': 1,
#    ' amazon com': 1,
#    'good amazon': 1,
#    ' terrible amazon': 1,
#    ' amazon warehouse': 1},
#   6,
#   ' much amazon',
#   6,
#   'terrible'],
#  [{' big smile': 1, ' happy happy thanks': 1}, 2, ' big smile', 2, 'happy'],
#  [{'great exterior condition screen': 1, 'good condition screen': 1},
#   2,
#   'great exterior condition screen',
#   2,
#   'great'],
#  [{' pink line': 1}, 1, ' pink line', 1, 'pink'],
#  [{'extra charging malfunction': 1,
#    ' charging use': 1,
#    ' brand charger charging trouble': 1},
#   3,
#   'extra charging malfunction',
#   3,
#   'extra'],
#  [{' much tape case': 1}, 1, ' much tape case', 1, 'much'],
#  [{'great great condition': 1,
#    'perfect condition': 4,
#    'fantastic condition problem': 1,
#    'great supposed condition': 1},
#   7,
#   'perfect condition',
#   4,
#   'perfect'],
#  [{' great ordering experience': 1},
#   1,
#   ' great ordering experience',
#   1,
#   'great'],
#  [{'tact phone': 1, 'sensitive phone': 1}, 2, 'tact phone', 2, 'tact'],
#  [{' option hardware': 1, ' hardware problem': 1},
#   2,
#   ' option hardware',
#   2,
#   'option'],
#  [{' exhausted problem phone': 1},
#   1,
#   ' exhausted problem phone',
#   1,
#   'exhausted'],
#  [{' turned disappointing high hope': 1},
#   1,
#   ' turned disappointing high hope',
#   1,
#   'turned'],
#  [{' test luck': 1}, 1, ' test luck', 1, 'test'],
#  [{' green silicone': 1}, 1, ' green silicone', 1, 'green'],
#  [{'small working issue': 1}, 1, 'small working issue', 1, 'small'],
#  [{' p button': 1}, 1, ' p button', 1, 'p'],
#  [{' cost beat': 1, 'good price': 1}, 2, ' cost beat', 2, 'good'],
#  [{' bad program': 1, ' failing bad software': 2},
#   3,
#   ' failing bad software',
#   2,
#   'failing'],
#  [{' get apps': 1,
#    ' several apps': 1,
#    ' download apps': 2,
#    ' system apps': 1,
#    ' major apps': 1,
#    ' searching apps': 1,
#    ' download application phone': 1},
#   8,
#   ' download apps',
#   7,
#   'system'],
#  [{'replacement son': 1, 'gift son': 1},
#   2,
#   'replacement son',
#   2,
#   'replacement'],
#  [{' son phone': 1,
#    'apple kid phone': 1,
#    ' iphone son': 1,
#    ' durable phone grandson': 1,
#    'phone son': 1},
#   5,
#   ' son phone',
#   5,
#   'son'],
#  [{' getting issue': 1, ' much getting problem': 1},
#   2,
#   ' getting issue',
#   2,
#   'much'],
#  [{' set phone fault': 1,
#    'damaging telefonolo': 1,
#    ' unintended contact phone': 1},
#   3,
#   ' set phone fault',
#   3,
#   'unintended'],
#  [{' broke store': 1, ' repair store': 1}, 2, ' broke store', 2, 'repair'],
#  [{' price replacement': 1, 'price condition': 1},
#   2,
#   ' price replacement',
#   2,
#   'price'],
#  [{' face time': 1}, 1, ' face time', 1, 'face'],
#  [{' time friend': 1}, 1, ' time friend', 1, 'time'],
#  [{'wifi device': 1}, 1, 'wifi device', 1, 'wifi'],
#  [{' month purchase': 1,
#    ' charge month': 1,
#    ' month processing': 1,
#    ' couple month': 1},
#   4,
#   ' month purchase',
#   4,
#   'month'],
#  [{'phone couple': 1, 'love phone': 2, 'phone boyfriend': 1},
#   4,
#   'love phone',
#   3,
#   'phone'],
#  [{'whole day': 1, ' pasted day': 1, ' day thing': 1, ' took day': 1},
#   4,
#   'whole day',
#   4,
#   'whole'],
#  [{' day power button': 1}, 1, ' day power button', 1, 'day'],
#  [{' customer rep phone': 1,
#    ' phone needed return': 1,
#    ' store telephone number': 1},
#   3,
#   ' customer rep phone',
#   3,
#   'store'],
#  [{' long time': 1, ' many time': 1}, 2, ' long time', 2, 'many'],
#  [{' t service': 1}, 1, ' t service', 1, 't'],
#  [{' big mistake': 1}, 1, ' big mistake', 1, 'big'],
#  [{' long negative story': 1}, 1, ' long negative story', 1, 'long'],
#  [{' verizon charge': 1}, 1, ' verizon charge', 1, 'verizon'],
#  [{' new service': 1, ' service adjustment': 1},
#   2,
#   ' new service',
#   2,
#   'service'],
#  [{' stupid lied refuse': 1}, 1, ' stupid lied refuse', 1, 'stupid'],
#  [{' verizon type': 1}, 1, ' verizon type', 1, 'verizon'],
#  [{'c gb storage': 1}, 1, 'c gb storage', 1, 'c'],
#  [{' plenty good deal price': 1,
#    ' deal price': 2,
#    ' new good price looking pas': 2,
#    ' acceptable price': 1,
#    ' good value price': 1,
#    ' perfect good price': 1},
#   8,
#   ' deal price',
#   6,
#   'plenty'],
#  [{'verizon network': 1}, 1, 'verizon network', 1, 'verizon'],
#  [{'failed recharging repairable purchase': 1},
#   1,
#   'failed recharging repairable purchase',
#   1,
#   'failed'],
#  [{' new phone': 8,
#    ' old phone': 1,
#    ' new card phone': 1,
#    ' classic phone': 1,
#    'new phone': 1,
#    'phone activate': 1,
#    ' samsung phone': 1,
#    ' update phone': 1},
#   15,
#   ' new phone',
#   8,
#   'update'],
#  [{'standing joke': 1}, 1, 'standing joke', 1, 'standing'],
#  [{' color phone': 1, 'white phone': 1}, 2, ' color phone', 2, 'white'],
#  [{' verizon store': 1}, 1, ' verizon store', 1, 'verizon'],
#  [{' store activate': 1}, 1, ' store activate', 1, 'store'],
#  [{' sim port': 1}, 1, ' sim port', 1, 'sim'],
#  [{' earbuds charger': 1}, 1, ' earbuds charger', 1, 'earbuds'],
#  [{' port key standard icon sticker': 1},
#   1,
#   ' port key standard icon sticker',
#   1,
#   'port'],
#  [{' fun spring green': 1}, 1, ' fun spring green', 1, 'fun'],
#  [{' week doorstep booted product': 1},
#   1,
#   ' week doorstep booted product',
#   1,
#   'week'],
#  [{' fine worked month': 1}, 1, ' fine worked month', 1, 'fine'],
#  [{' next iphone': 1, ' another iphone': 1, ' new iphone': 1},
#   3,
#   ' next iphone',
#   3,
#   'next'],
#  [{' restocking fee': 1}, 1, ' restocking fee', 1, 'restocking'],
#  [{' nice fun': 1}, 1, ' nice fun', 1, 'nice'],
#  [{' fun color': 1, ' color working': 1}, 2, ' fun color', 2, 'fun'],
#  [{' worked working worth vendor': 1},
#   1,
#   ' worked working worth vendor',
#   1,
#   'worked'],
#  [{' android phone keep': 1, ' phone stay': 1},
#   2,
#   ' android phone keep',
#   2,
#   'phone'],
#  [{' intuitive use': 1}, 1, ' intuitive use', 1, 'intuitive'],
#  [{' responsive reason': 1}, 1, ' responsive reason', 1, 'responsive'],
#  [{' imei verification': 1}, 1, ' imei verification', 1, 'imei'],
#  [{' star sure standard seller star': 1},
#   1,
#   ' star sure standard seller star',
#   1,
#   'star'],
#  [{'want return': 1, ' want return': 1}, 2, 'want return', 2, 'want'],
#  [{' descent value': 1, ' lesser value': 1}, 2, ' descent value', 2, 'lesser'],
#  [{' fortune phone': 1}, 1, ' fortune phone', 1, 'fortune'],
#  [{'verizon wireless phone': 1}, 1, 'verizon wireless phone', 1, 'verizon'],
#  [{' unable use': 1, ' no using issue': 1}, 2, ' unable use', 2, 'unable'],
#  [{'bit phone': 1}, 1, 'bit phone', 1, 'bit'],
#  [{' easier bbrewer polite': 1}, 1, ' easier bbrewer polite', 1, 'easier'],
#  [{' excellent experience item': 2, 'great experience product': 1},
#   3,
#   ' excellent experience item',
#   2,
#   'great'],
#  [{' original packaging': 2}, 2, ' original packaging', 1, 'original'],
#  [{'needed enter pin': 2}, 2, 'needed enter pin', 1, 'needed'],
#  [{' anyonecan gime advice': 2}, 2, ' anyonecan gime advice', 1, 'anyonecan'],
#  [{'excited unlocked easy set': 2},
#   2,
#   'excited unlocked easy set',
#   1,
#   'excited'],
#  [{' noticeable damage scratch': 2, 'heavy scratch': 2},
#   4,
#   ' noticeable damage scratch',
#   2,
#   'noticeable'],
#  [{' mess play': 2}, 2, ' mess play', 1, 'mess'],
#  [{' poor hour': 2, ' hour minute': 2}, 4, ' poor hour', 2, 'poor'],
#  [{' hour usage hour': 2}, 2, ' hour usage hour', 1, 'hour'],
#  [{' no added apps': 4,
#    ' no apps': 1,
#    'no apps': 1,
#    'new apps': 1,
#    ' no apps software': 1},
#   8,
#   ' no added apps',
#   5,
#   'no'],
#  [{' setting standard': 2}, 2, ' setting standard', 1, 'setting'],
#  [{' researching problem': 2, 'research buying': 1},
#   3,
#   ' researching problem',
#   2,
#   'researching'],
#  [{' screen protector': 4, 'us screen protector': 2},
#   6,
#   ' screen protector',
#   2,
#   'us'],
#  [{' remove straight box': 2}, 2, ' remove straight box', 1, 'remove'],
#  [{' hr recharge': 2}, 2, ' hr recharge', 1, 'hr'],
#  [{' shipping money': 2}, 2, ' shipping money', 1, 'shipping'],
#  [{' incompetent repair center': 2},
#   2,
#   ' incompetent repair center',
#   1,
#   'incompetent'],
#  [{' replace kit wish': 2}, 2, ' replace kit wish', 1, 'replace'],
#  [{' protector day rest fine': 2},
#   2,
#   ' protector day rest fine',
#   1,
#   'protector'],
#  [{'iphone unlocked factory': 2,
#    ' unlocked iphone work': 1,
#    ' iphone factory': 1},
#   4,
#   'iphone unlocked factory',
#   3,
#   'unlocked'],
#  [{' net right': 2}, 2, ' net right', 1, 'net'],
#  [{' paid iphone': 2}, 2, ' paid iphone', 1, 'paid'],
#  [{' no major scratch charger work': 2},
#   2,
#   ' no major scratch charger work',
#   1,
#   'no'],
#  [{' dollar store': 2}, 2, ' dollar store', 1, 'dollar'],
#  [{' unlocked argentina': 2}, 2, ' unlocked argentina', 1, 'unlocked'],
#  [{'advertised work': 2}, 2, 'advertised work', 1, 'advertised'],
#  [{'phone owning month': 2}, 2, 'phone owning month', 1, 'phone'],
#  [{' life proof': 2}, 2, ' life proof', 1, 'life'],
#  [{' proof case': 2}, 2, ' proof case', 1, 'proof'],
#  [{' loose software advertised problem': 2},
#   2,
#   ' loose software advertised problem',
#   1,
#   'loose'],
#  [{'dent corner': 2, 'scratch dent': 1}, 3, 'dent corner', 2, 'scratch'],
#  [{' brand factory unlocked gsm': 2},
#   2,
#   ' brand factory unlocked gsm',
#   1,
#   'brand'],
#  [{' iphone gb': 2,
#    ' generation iphone itunes': 1,
#    ' outdated iphone': 1,
#    ' iphone box': 1,
#    'shipping iphone': 1,
#    'description iphone': 1},
#   7,
#   ' iphone gb',
#   6,
#   'shipping'],
#  [{'constant issue': 2}, 2, 'constant issue', 1, 'constant'],
#  [{' blue screen': 2}, 2, ' blue screen', 1, 'blue'],
#  [{' screen death': 2, ' worse dead show screen': 1},
#   3,
#   ' screen death',
#   2,
#   'worse'],
#  [{' multiple time': 2}, 2, ' multiple time', 1, 'multiple'],
#  [{' time phone refuse': 2}, 2, ' time phone refuse', 1, 'time'],
#  [{' refuse charge': 2}, 2, ' refuse charge', 1, 'refuse'],
#  [{' randomly shuts': 2}, 2, ' randomly shuts', 1, 'randomly'],
#  [{' shuts screen': 2}, 2, ' shuts screen', 1, 'shuts'],
#  [{'thanks daughter': 2}, 2, 'thanks daughter', 1, 'thanks'],
#  [{'hot use': 2}, 2, 'hot use', 1, 'hot'],
#  [{'battery going percentage': 2,
#    ' battery point': 1,
#    ' charged battery': 1,
#    ' battery line': 1},
#   5,
#   'battery going percentage',
#   4,
#   'charged'],
#  [{' store used find': 2}, 2, ' store used find', 1, 'store'],
#  [{' failing took software': 2}, 2, ' failing took software', 1, 'failing'],
#  [{'good issue': 2}, 2, 'good issue', 1, 'good'],
#  [{' fake plastic': 2}, 2, ' fake plastic', 1, 'fake'],
#  [{'worst working mobile': 2}, 2, 'worst working mobile', 1, 'worst'],
#  [{' trust seller': 2, ' trusted seller': 1},
#   3,
#   ' trust seller',
#   2,
#   'trusted'],
#  [{'new unlocked item': 2}, 2, 'new unlocked item', 1, 'new'],
#  [{' new lot': 2}, 2, ' new lot', 1, 'new'],
#  [{' brand lot dust': 2}, 2, ' brand lot dust', 1, 'brand'],
#  [{'stated verizon': 2}, 2, 'stated verizon', 1, 'stated'],
#  [{' trying called figure': 2}, 2, ' trying called figure', 1, 'trying'],
#  [{'satisfied product': 2,
#    'happy product': 2,
#    'awesome happy product service': 1,
#    'expected good product': 1,
#    ' no problem product': 1,
#    ' satisfied purchase': 1},
#   8,
#   'satisfied product',
#   6,
#   'satisfied'],
#  [{' early perfect loving condition': 2},
#   2,
#   ' early perfect loving condition',
#   1,
#   'early'],
#  [{' delivery thank': 2, ' delivery prompt': 1},
#   3,
#   ' delivery thank',
#   2,
#   'delivery'],
#  [{'month iphone': 2}, 2, 'month iphone', 1, 'month'],
#  [{' phone carpet': 2}, 2, ' phone carpet', 1, 'phone'],
#  [{' carpet feat le protective case': 2},
#   2,
#   ' carpet feat le protective case',
#   1,
#   'carpet'],
#  [{' case starting reason': 2}, 2, ' case starting reason', 1, 'case'],
#  [{' wire pay': 2}, 2, ' wire pay', 1, 'wire'],
#  [{' fixed buy': 2, ' solid buy': 1}, 3, ' fixed buy', 2, 'solid'],
#  [{'good value': 2}, 2, 'good value', 1, 'good'],
#  [{' line goin': 1, ' line show': 1}, 2, ' line goin', 2, 'line'],
#  [{'quick functioning product': 1},
#   1,
#   'quick functioning product',
#   1,
#   'quick'],
#  [{'able configure connecting trying working download': 1},
#   1,
#   'able configure connecting trying working download',
#   1,
#   'able'],
#  [{' mobile repair': 2}, 2, ' mobile repair', 1, 'mobile'],
#  [{' refurbished new mobile amazon': 1},
#   1,
#   ' refurbished new mobile amazon',
#   1,
#   'refurbished'],
#  [{' mentioned first frustating experience': 1},
#   1,
#   ' mentioned first frustating experience',
#   1,
#   'mentioned'],
#  [{' usd change screen': 1}, 1, ' usd change screen', 1, 'usd'],
#  [{' gic problem': 1}, 1, ' gic problem', 1, 'gic'],
#  [{'new put condition': 1, 'new condition': 3}, 4, 'new condition', 2, 'new'],
#  [{' phone fine found beware': 1}, 1, ' phone fine found beware', 1, 'phone'],
#  [{'water purchased damage': 1, 'water damage': 1, ' water damage': 1},
#   3,
#   'water purchased damage',
#   3,
#   'water'],
#  [{' new holding stop': 1}, 1, ' new holding stop', 1, 'new'],
#  [{' liquid indicator': 1}, 1, ' liquid indicator', 1, 'liquid'],
#  [{' based activated serial': 1}, 1, ' based activated serial', 1, 'based'],
#  [{'best thing': 1}, 1, 'best thing', 1, 'best'],
#  [{'perfect little defecto screen': 1},
#   1,
#   'perfect little defecto screen',
#   1,
#   'perfect'],
#  [{' resolve problem': 1}, 1, ' resolve problem', 1, 'resolve'],
#  [{' enough info': 1}, 1, ' enough info', 1, 'enough'],
#  [{'no good iphone camera work': 1}, 1, 'no good iphone camera work', 1, 'no'],
#  [{' d work': 1}, 1, ' d work', 1, 'd'],
#  [{' beautiful picture': 1}, 1, ' beautiful picture', 1, 'beautiful'],
#  [{'sealed box': 1, 'sealed apple box': 1}, 2, 'sealed box', 2, 'sealed'],
#  [{' no apple warranty': 1, ' checked apple warranty': 1},
#   2,
#   ' no apple warranty',
#   2,
#   'no'],
#  [{' past return date': 1}, 1, ' past return date', 1, 'past'],
#  [{' prompt service': 1}, 1, ' prompt service', 1, 'prompt'],
#  [{' happy purchase': 1, ' pleased purchase thank': 1},
#   2,
#   ' happy purchase',
#   2,
#   'pleased'],
#  [{'samsung couple': 1}, 1, 'samsung couple', 1, 'samsung'],
#  [{' everyone family': 1}, 1, ' everyone family', 1, 'everyone'],
#  [{' used great thing': 1, 'great use': 1, 'perfect used item': 1},
#   3,
#   ' used great thing',
#   3,
#   'used'],
#  [{' fastest phone': 1, ' faster phone problem': 1},
#   2,
#   ' fastest phone',
#   2,
#   'fastest'],
#  [{' thumbprint password': 1, ' password feature': 1},
#   2,
#   ' thumbprint password',
#   2,
#   'thumbprint'],
#  [{' miss swipe': 1}, 1, ' miss swipe', 1, 'miss'],
#  [{' cool feature swipe typing': 1},
#   1,
#   ' cool feature swipe typing',
#   1,
#   'cool'],
#  [{'high end': 1}, 1, 'high end', 1, 'high'],
#  [{' end tell': 1}, 1, ' end tell', 1, 'end'],
#  [{' top notch product': 1}, 1, ' top notch product', 1, 'top'],
#  [{' unlocked use': 1, ' unlock use': 1}, 2, ' unlocked use', 2, 'unlocked'],
#  [{'nice term': 1}, 1, 'nice term', 1, 'nice'],
#  [{' term worked mobile network': 1},
#   1,
#   ' term worked mobile network',
#   1,
#   'term'],
#  [{'died month return policy': 1}, 1, 'died month return policy', 1, 'died'],
#  [{'bought gifted father': 1}, 1, 'bought gifted father', 1, 'bought'],
#  [{' total treachery': 1}, 1, ' total treachery', 1, 'total'],
#  [{'turn turn charge': 1, ' needed turn': 1},
#   2,
#   'turn turn charge',
#   2,
#   'turn'],
#  [{'hate thing': 1}, 1, 'hate thing', 1, 'hate'],
#  [{' n thing wife': 1}, 1, ' n thing wife', 1, 'n'],
#  [{' iphone birthday': 1}, 1, ' iphone birthday', 1, 'iphone'],
#  [{' stand use': 1}, 1, ' stand use', 1, 'stand'],
#  [{' mine home apple': 1}, 1, ' mine home apple', 1, 'mine'],
#  [{' intuitive throw thing': 1}, 1, ' intuitive throw thing', 1, 'intuitive'],
#  [{' thing wall': 1}, 1, ' thing wall', 1, 'thing'],
#  [{' star fact': 1, 'star item': 1}, 2, ' star fact', 2, 'star'],
#  [{' mobile wife': 1}, 1, ' mobile wife', 1, 'mobile'],
#  [{' wife telling tolerates': 1}, 1, ' wife telling tolerates', 1, 'wife'],
#  [{'easy transfer': 1}, 1, 'easy transfer', 1, 'easy'],
#  [{' transfer data iphone': 1}, 1, ' transfer data iphone', 1, 'transfer'],
#  [{'returned item': 1}, 1, 'returned item', 1, 'returned'],
#  [{'matched description': 1}, 1, 'matched description', 1, 'matched'],
#  [{' no good job': 1}, 1, ' no good job', 1, 'no'],
#  [{'described unlocked husband': 1},
#   1,
#   'described unlocked husband',
#   1,
#   'described'],
#  [{' old iphones': 1, ' old old phone': 1, 'old iphone': 1},
#   3,
#   ' old iphones',
#   3,
#   'old'],
#  [{'new function work': 1}, 1, 'new function work', 1, 'new'],
#  [{'fine serve purpose': 1}, 1, 'fine serve purpose', 1, 'fine'],
#  [{'next phone amazon': 1}, 1, 'next phone amazon', 1, 'next'],
#  [{' craigslist letgo': 1}, 1, ' craigslist letgo', 1, 'craigslist'],
#  [{'phone thanx': 1}, 1, 'phone thanx', 1, 'phone'],
#  [{' best thanx man': 1}, 1, ' best thanx man', 1, 'best'],
#  [{'emailed seller': 1, ' email fact': 1}, 2, 'emailed seller', 2, 'emailed'],
#  [{' ready use': 1}, 1, ' ready use', 1, 'ready'],
#  [{' new scuff top': 1}, 1, ' new scuff top', 1, 'new'],
#  [{' unlocked checked apple': 1}, 1, ' unlocked checked apple', 1, 'unlocked'],
#  [{' professional locked': 1}, 1, ' professional locked', 1, 'professional'],
#  [{' no answer': 1}, 1, ' no answer', 1, 'no'],
#  [{' unlocked phone work': 1,
#    'unlock phone': 1,
#    'phone unlocked trusting': 1,
#    'unlocked received phone': 1,
#    ' u unlock phone': 1,
#    ' unlock phone': 1},
#   6,
#   ' unlocked phone work',
#   6,
#   'unlocked'],
#  [{' work tell beware': 1}, 1, ' work tell beware', 1, 'work'],
#  [{'great gift': 1,
#    'gift work': 1,
#    'turned perfect gift': 1,
#    ' perfect gift': 1},
#   4,
#   'great gift',
#   4,
#   'turned'],
#  [{'telephone lot': 1}, 1, 'telephone lot', 1, 'telephone'],
#  [{' networking problem': 1}, 1, ' networking problem', 1, 'networking'],
#  [{' problem time network': 1}, 1, ' problem time network', 1, 'problem'],
#  [{' new odd thing': 1, ' new another small thing': 1},
#   2,
#   ' new odd thing',
#   2,
#   'new'],
#  [{' customer guaranteed service': 1},
#   1,
#   ' customer guaranteed service',
#   1,
#   'customer'],
#  [{' language apps': 1}, 1, ' language apps', 1, 'language'],
#  [{' many sub menu': 1}, 1, ' many sub menu', 1, 'many'],
#  [{' primary language': 1, ' language english': 1},
#   2,
#   ' primary language',
#   2,
#   'primary'],
#  [{' spanish second language': 1},
#   1,
#   ' spanish second language',
#   1,
#   'spanish'],
#  [{' chinese sign': 1}, 1, ' chinese sign', 1, 'chinese'],
#  [{'screw plate': 1, ' missing screw': 1}, 2, 'screw plate', 2, 'screw'],
#  [{' plate top': 1}, 1, ' plate top', 1, 'plate'],
#  [{' lcd connector': 1}, 1, ' lcd connector', 1, 'lcd'],
#  [{' missing top bad condition': 1},
#   1,
#   ' missing top bad condition',
#   1,
#   'missing'],
#  [{' great hold': 1}, 1, ' great hold', 1, 'great'],
#  [{' tmobile delivery': 1}, 1, ' tmobile delivery', 1, 'tmobile'],
#  [{'defective start waste money': 1},
#   1,
#   'defective start waste money',
#   1,
#   'defective'],
#  [{'day earlyer': 1}, 1, 'day earlyer', 1, 'day'],
#  [{' new original package': 1}, 1, ' new original package', 1, 'new'],
#  [{'better deal': 1, ' good bargain': 1}, 2, 'better deal', 2, 'good'],
#  [{'supposed problem payment': 1},
#   1,
#   'supposed problem payment',
#   1,
#   'supposed'],
#  [{' visa camera': 1}, 1, ' visa camera', 1, 'visa'],
#  [{' work upsetting': 1}, 1, ' work upsetting', 1, 'work'],
#  [{'slow many ipads': 1, ' slow long load': 1},
#   2,
#   'slow many ipads',
#   2,
#   'slow'],
#  [{'good shapthanks': 1}, 1, 'good shapthanks', 1, 'good'],
#  [{'great basic design': 1}, 1, 'great basic design', 1, 'great'],
#  [{' newer model': 1}, 1, ' newer model', 1, 'newer'],
#  [{' compatible icloud': 1, ' contact icloud': 1},
#   2,
#   ' compatible icloud',
#   2,
#   'contact'],
#  [{' apps version app': 1, ' newest good apps': 1},
#   2,
#   ' apps version app',
#   2,
#   'newest'],
#  [{' st generation': 1}, 1, ' st generation', 1, 'st'],
#  [{' want download': 1, ' music download': 1, ' download music': 1},
#   3,
#   ' want download',
#   3,
#   'want'],
#  [{' older compatible version': 1},
#   1,
#   ' older compatible version',
#   1,
#   'older'],
#  [{' work phone': 2}, 2, ' work phone', 1, 'work'],
#  [{' phone course': 1, ' phone advice': 1}, 2, ' phone course', 2, 'phone'],
#  [{' buy condition battery brand': 1,
#    ' battery delievred item': 1,
#    ' used seller battery end': 1},
#   3,
#   ' buy condition battery brand',
#   3,
#   'used'],
#  [{' new hold day': 1}, 1, ' new hold day', 1, 'new'],
#  [{'slight damage dayle': 1}, 1, 'slight damage dayle', 1, 'slight'],
#  [{' tear phone': 1}, 1, ' tear phone', 1, 'tear'],
#  [{' big chunk': 1}, 1, ' big chunk', 1, 'big'],
#  [{' whole bottom corner': 1}, 1, ' whole bottom corner', 1, 'whole'],
#  [{' effected screen charger': 1},
#   1,
#   ' effected screen charger',
#   1,
#   'effected'],
#  [{' little smaller dime': 1, ' little money': 1},
#   2,
#   ' little smaller dime',
#   2,
#   'little'],
#  [{' charger port': 1,
#    ' phone charger': 1,
#    'free charger': 1,
#    ' cable charger': 1},
#   4,
#   ' charger port',
#   4,
#   'phone'],
#  [{'g work': 1}, 1, 'g work', 1, 'g'],
#  [{' basic cool hold': 1}, 1, ' basic cool hold', 1, 'basic'],
#  [{' right amount': 1}, 1, ' right amount', 1, 'right'],
#  [{' good com stuff': 1}, 1, ' good com stuff', 1, 'good'],
#  [{' cheap skeptical': 1}, 1, ' cheap skeptical', 1, 'cheap'],
#  [{' shop line': 1}, 1, ' shop line', 1, 'shop'],
#  [{' debit card': 1}, 1, ' debit card', 1, 'debit'],
#  [{' much need': 1}, 1, ' much need', 1, 'much'],
#  [{' school birthday': 1}, 1, ' school birthday', 1, 'school'],
#  [{'g work iphone': 1}, 1, 'g work iphone', 1, 'g'],
#  [{' well ring volume': 1}, 1, ' well ring volume', 1, 'well'],
#  [{' sim chip': 1, ' another sim tray': 1}, 2, ' sim chip', 2, 'sim'],
#  [{' better quality control': 1}, 1, ' better quality control', 1, 'better'],
#  [{'jailbreak unlock': 1, ' untethered jailbreak io': 1},
#   2,
#   'jailbreak unlock',
#   2,
#   'untethered'],
#  [{' every experience': 1}, 1, ' every experience', 1, 'every'],
#  [{'no compatible verizon': 1}, 1, 'no compatible verizon', 1, 'no'],
#  [{' old way': 1}, 1, ' old way', 1, 'old'],
#  [{' looking frozen start screen': 1},
#   1,
#   ' looking frozen start screen',
#   1,
#   'looking'],
#  [{' subsidiary warehouse': 1,
#    ' placed order warehouse deal warehouse': 1,
#    ' warehouse deal inventory': 1},
#   3,
#   ' subsidiary warehouse',
#   3,
#   'warehouse'],
#  [{' unable replace order': 1}, 1, ' unable replace order', 1, 'unable'],
#  [{' printer print return': 1}, 1, ' printer print return', 1, 'printer'],
#  [{' return label': 1}, 1, ' return label', 1, 'return'],
#  [{' bussiness day': 1}, 1, ' bussiness day', 1, 'bussiness'],
#  [{'new condition problem': 1, ' new good condition': 1},
#   2,
#   'new condition problem',
#   2,
#   'new'],
#  [{' newest generation': 1}, 1, ' newest generation', 1, 'newest'],
#  [{' current charge iphone': 1}, 1, ' current charge iphone', 1, 'current'],
#  [{' dead phone': 1, 'disappointed phone': 1, ' unusable phone': 1},
#   3,
#   ' dead phone',
#   3,
#   'unusable'],
#  [{' signed year': 1, ' year contract': 1}, 2, ' signed year', 2, 'year'],
#  [{' new contract time': 1}, 1, ' new contract time', 1, 'new'],
#  [{' mess phone light': 1}, 1, ' mess phone light', 1, 'mess'],
#  [{' light scratch': 1}, 1, ' light scratch', 1, 'light'],
#  [{' work return': 1}, 1, ' work return', 1, 'work'],
#  [{' day policy lesson': 1}, 1, ' day policy lesson', 1, 'day'],
#  [{'broken thought': 1, ' locked thought': 1},
#   2,
#   'broken thought',
#   2,
#   'locked'],
#  [{'no internet': 1}, 1, 'no internet', 1, 'no'],
#  [{' unlocked money speaker': 1}, 1, ' unlocked money speaker', 1, 'unlocked'],
#  [{'liked iphone place': 1}, 1, 'liked iphone place', 1, 'liked'],
#  [{'advertised function': 1}, 1, 'advertised function', 1, 'advertised'],
#  [{' camera surf': 1, ' feature camera': 1, ' camera web': 1},
#   3,
#   ' camera surf',
#   3,
#   'feature'],
#  [{' simple used surf web': 1}, 1, ' simple used surf web', 1, 'simple'],
#  [{'able unlocked verizon': 1}, 1, 'able unlocked verizon', 1, 'able'],
#  [{' volume button': 1}, 1, ' volume button', 1, 'volume'],
#  [{' nervous buying condition love': 1},
#   1,
#   ' nervous buying condition love',
#   1,
#   'nervous'],
#  [{'itthe cheap useablei': 1}, 1, 'itthe cheap useablei', 1, 'itthe'],
#  [{'worst bought thing': 1}, 1, 'worst bought thing', 1, 'worst'],
#  [{' broke month': 1}, 1, ' broke month', 1, 'broke'],
#  [{' lit fire': 1}, 1, ' lit fire', 1, 'lit'],
#  [{'pay shop fix': 1, ' pay store': 1}, 2, 'pay shop fix', 2, 'pay'],
#  [{' see problem': 1}, 1, ' see problem', 1, 'see'],
#  [{' assembled mute button': 1}, 1, ' assembled mute button', 1, 'assembled'],
#  [{' perfect thing': 1}, 1, ' perfect thing', 1, 'perfect'],
#  [{' extra fee unlock': 1,
#    ' unlocked returned expense': 1,
#    ' costed extra unlocked unit': 1},
#   3,
#   ' extra fee unlock',
#   3,
#   'unlocked'],
#  [{' huge money selling shame': 1}, 1, ' huge money selling shame', 1, 'huge'],
#  [{' unusable ripping': 1}, 1, ' unusable ripping', 1, 'unusable'],
#  [{'operating system': 1}, 1, 'operating system', 1, 'operating'],
#  [{' grocery store': 1}, 1, ' grocery store', 1, 'grocery'],
#  [{' local store weather channel': 1},
#   1,
#   ' local store weather channel',
#   1,
#   'local'],
#  [{' older apps': 1, ' old support apps': 1}, 2, ' older apps', 2, 'older'],
#  [{'rate item': 1}, 1, 'rate item', 1, 'rate'],
#  [{' description contacted monsterbuyback': 1},
#   1,
#   ' description contacted monsterbuyback',
#   1,
#   'description'],
#  [{' speedy return': 1}, 1, ' speedy return', 1, 'speedy'],
#  [{' cooperative apologized great company': 1},
#   1,
#   ' cooperative apologized great company',
#   1,
#   'cooperative'],
#  [{' reputable trustworthy thanks': 1},
#   1,
#   ' reputable trustworthy thanks',
#   1,
#   'reputable'],
#  [{'great shape': 1}, 1, 'great shape', 1, 'great'],
#  [{' great devilery': 1}, 1, ' great devilery', 1, 'great'],
#  [{' buena comunicacion': 1}, 1, ' buena comunicacion', 1, 'buena'],
#  [{' seller godblessxoxo': 1}, 1, ' seller godblessxoxo', 1, 'seller'],
#  [{' many different company': 1}, 1, ' many different company', 1, 'many'],
#  [{' overall satisfied word place telling holder': 1},
#   1,
#   ' overall satisfied word place telling holder',
#   1,
#   'overall'],
#  [{' emergency purpose': 1}, 1, ' emergency purpose', 1, 'emergency'],
#  [{' feature use': 1}, 1, ' feature use', 1, 'feature'],
#  [{' use car': 1}, 1, ' use car', 1, 'use'],
#  [{'prepaid att service': 1}, 1, 'prepaid att service', 1, 'prepaid'],
#  [{' sure order': 1}, 1, ' sure order', 1, 'sure'],
#  [{' happy box': 1}, 1, ' happy box', 1, 'happy'],
#  [{' unlocked order': 1}, 1, ' unlocked order', 1, 'unlocked'],
#  [{' send want': 1}, 1, ' send want', 1, 'send'],
#  [{' feature price': 1}, 1, ' feature price', 1, 'feature'],
#  [{' comfortable recommending fact': 1},
#   1,
#   ' comfortable recommending fact',
#   1,
#   'comfortable'],
#  [{' moment thing': 1}, 1, ' moment thing', 1, 'moment'],
#  [{' video store': 1}, 1, ' video store', 1, 'video'],
#  [{'new cell': 1}, 1, 'new cell', 1, 'new'],
#  [{' multiple registration number': 1},
#   1,
#   ' multiple registration number',
#   1,
#   'multiple'],
#  [{' many problem': 2}, 2, ' many problem', 1, 'many'],
#  [{' point apps': 1}, 1, ' point apps', 1, 'point'],
#  [{' newer version wtf': 1}, 1, ' newer version wtf', 1, 'newer'],
#  [{' upgradeable grandson day': 1},
#   1,
#   ' upgradeable grandson day',
#   1,
#   'upgradeable'],
#  [{'decent shape owner': 1}, 1, 'decent shape owner', 1, 'decent'],
#  [{' old otterbox': 1, ' otter box cover': 1}, 2, ' old otterbox', 2, 'otter'],
#  [{' unusable school': 1}, 1, ' unusable school', 1, 'unusable'],
#  [{' net prepaid held learned phone': 1},
#   1,
#   ' net prepaid held learned phone',
#   1,
#   'net'],
#  [{' guess lesson': 1}, 1, ' guess lesson', 1, 'guess'],
#  [{' product defectiveness': 1}, 1, ' product defectiveness', 1, 'product'],
#  [{' used defectiveness shipment': 1},
#   1,
#   ' used defectiveness shipment',
#   1,
#   'used'],
#  [{'open program': 1}, 1, 'open program', 1, 'open'],
#  [{' program running background': 1},
#   1,
#   ' program running background',
#   1,
#   'program'],
#  [{'puchase vintage': 1}, 1, 'puchase vintage', 1, 'puchase'],
#  [{' happy vintage fun phone': 1}, 1, ' happy vintage fun phone', 1, 'happy'],
#  [{'no belief': 1}, 1, 'no belief', 1, 'no'],
#  [{' phone fraud': 1}, 1, ' phone fraud', 1, 'phone'],
#  [{'call horrible phone': 1}, 1, 'call horrible phone', 1, 'call'],
#  [{'piece screen': 1}, 1, 'piece screen', 1, 'piece'],
#  [{' total disaster': 1}, 1, ' total disaster', 1, 'total'],
#  [{' honest supplierhowever': 1}, 1, ' honest supplierhowever', 1, 'honest'],
#  [{' supplier messed purchased used thing': 1},
#   1,
#   ' supplier messed purchased used thing',
#   1,
#   'supplier'],
#  [{' great slot internet work': 1},
#   1,
#   ' great slot internet work',
#   1,
#   'great'],
#  [{' every one': 1}, 1, ' every one', 1, 'every'],
#  [{'great love': 1, ' loved moment': 1}, 2, 'great love', 2, 'loved'],
#  [{' form u': 1}, 1, ' form u', 1, 'form'],
#  [{' star rating': 2}, 2, ' star rating', 1, 'star'],
#  [{' disabled upgrade': 1}, 1, ' disabled upgrade', 1, 'disabled'],
#  [{' good calling texting': 1}, 1, ' good calling texting', 1, 'good'],
#  [{' searching web': 1}, 1, ' searching web', 1, 'searching'],
#  [{' great deal': 1}, 1, ' great deal', 1, 'great'],
#  [{'worst iphone': 1}, 1, 'worst iphone', 1, 'worst'],
#  [{' phone paperweight': 1, ' paperweight phone': 1},
#   2,
#   ' phone paperweight',
#   2,
#   'phone'],
#  [{' facebook twitter': 1}, 1, ' facebook twitter', 1, 'facebook'],
#  [{' fourth apps': 1}, 1, ' fourth apps', 1, 'fourth'],
#  [{' phone static': 1}, 1, ' phone static', 1, 'phone'],
#  [{' static sound': 1}, 1, ' static sound', 1, 'static'],
#  [{' weird clicking noise unlock phone phone': 1},
#   1,
#   ' weird clicking noise unlock phone phone',
#   1,
#   'weird'],
#  [{' another account': 1}, 1, ' another account', 1, 'another'],
#  [{' music erase': 1}, 1, ' music erase', 1, 'music'],
#  [{' tried erase phone start': 1}, 1, ' tried erase phone start', 1, 'tried'],
#  [{' app store': 1}, 1, ' app store', 1, 'app'],
#  [{' another email': 1}, 1, ' another email', 1, 'another'],
#  [{' going reply': 1}, 1, ' going reply', 1, 'going'],
#  [{' reset setting turn': 1}, 1, ' reset setting turn', 1, 'reset'],
#  [{' advice purchase': 1}, 1, ' advice purchase', 1, 'advice'],
#  [{' back purchase iphone': 1}, 1, ' back purchase iphone', 1, 'back'],
#  [{' higher money': 1}, 1, ' higher money', 1, 'higher'],
#  [{' good ipod player': 1}, 1, ' good ipod player', 1, 'good'],
#  [{' good good digital picture frame': 1},
#   1,
#   ' good good digital picture frame',
#   1,
#   'good'],
#  [{' child game': 1}, 1, ' child game', 1, 'child'],
#  [{' no big thought deal': 1}, 1, ' no big thought deal', 1, 'no'],
#  [{' description thank': 1}, 1, ' description thank', 1, 'description'],
#  [{' r firmware': 1, ' firmware work': 1}, 2, ' r firmware', 2, 'r'],
#  [{' described whited excellent thank': 1},
#   1,
#   ' described whited excellent thank',
#   1,
#   'described'],
#  [{' backup phone music': 1}, 1, ' backup phone music', 1, 'backup'],
#  [{' basic music player': 1, ' downloaded music': 1},
#   2,
#   ' basic music player',
#   2,
#   'downloaded'],
#  [{'lit ringer button move': 1}, 1, 'lit ringer button move', 1, 'lit'],
#  [{' tray store fix waste money': 1},
#   1,
#   ' tray store fix waste money',
#   1,
#   'tray'],
#  [{' money scam': 1}, 1, ' money scam', 1, 'money'],
#  [{' outstanding meet expectation': 1},
#   1,
#   ' outstanding meet expectation',
#   1,
#   'outstanding'],
#  [{'expected lot': 1}, 1, 'expected lot', 1, 'expected'],
#  [{' problem miss iphone': 1}, 1, ' problem miss iphone', 1, 'problem'],
#  [{' money useless device': 1}, 1, ' money useless device', 1, 'money'],
#  [{'fine week': 1, ' week turn': 1}, 2, 'fine week', 2, 'week'],
#  [{' unlocked son': 1}, 1, ' unlocked son', 1, 'unlocked'],
#  [{' expected work': 1}, 1, ' expected work', 1, 'expected'],
#  [{'visible front clean delivery': 1},
#   1,
#   'visible front clean delivery',
#   1,
#   'visible'],
#  [{' unlock dealer': 1}, 1, ' unlock dealer', 1, 'unlock'],
#  [{'brand new granddaughter': 1}, 1, 'brand new granddaughter', 1, 'brand'],
#  [{' care move': 1}, 1, ' care move', 1, 'care'],
#  [{'tried charge': 1}, 1, 'tried charge', 1, 'tried'],
#  [{'incorrect product customer service': 1},
#   1,
#   'incorrect product customer service',
#   1,
#   'incorrect'],
#  [{' blemish programming': 1}, 1, ' blemish programming', 1, 'blemish'],
#  [{' complaint menu': 1}, 1, ' complaint menu', 1, 'complaint'],
#  [{' crisp press': 1}, 1, ' crisp press', 1, 'crisp'],
#  [{' press feel': 1}, 1, ' press feel', 1, 'press'],
#  [{' latest running software': 1}, 1, ' latest running software', 1, 'latest'],
#  [{' smart phone g': 1}, 1, ' smart phone g', 1, 'smart'],
#  [{' great hand': 1}, 1, ' great hand', 1, 'great'],
#  [{' new angry item': 1}, 1, ' new angry item', 1, 'new'],
#  [{'love seller': 1}, 1, 'love seller', 1, 'love'],
#  [{' cheap bet thing': 1}, 1, ' cheap bet thing', 1, 'cheap'],
#  [{' thing factory': 1}, 1, ' thing factory', 1, 'thing'],
#  [{'look new freeze': 1}, 1, 'look new freeze', 1, 'look'],
#  [{'no surprise work function': 1}, 1, 'no surprise work function', 1, 'no'],
#  [{' invalid sim message': 1}, 1, ' invalid sim message', 1, 'invalid'],
#  [{' red battery': 1, ' dy battery': 1, ' somehimes battery': 1},
#   3,
#   ' red battery',
#   3,
#   'somehimes'],
#  [{'box ringer': 1}, 1, 'box ringer', 1, 'box'],
#  [{' mute switch': 1}, 1, ' mute switch', 1, 'mute'],
#  [{' switch work': 1}, 1, ' switch work', 1, 'switch'],
#  [{' ringer work seller': 1}, 1, ' ringer work seller', 1, 'ringer'],
#  [{' mine sound': 1}, 1, ' mine sound', 1, 'mine'],
#  [{' broken mute ringer': 1}, 1, ' broken mute ringer', 1, 'broken'],
#  [{' indifferent ringer able switch': 1},
#   1,
#   ' indifferent ringer able switch',
#   1,
#   'indifferent'],
#  [{' ask lot': 1, ' careful lot question': 1}, 2, ' ask lot', 2, 'careful'],
#  [{' condition butit': 1}, 1, ' condition butit', 1, 'condition'],
#  [{' pay dollarsworth work': 1}, 1, ' pay dollarsworth work', 1, 'pay'],
#  [{' college class': 1}, 1, ' college class', 1, 'college'],
#  [{' class cincinnati': 1}, 1, ' class cincinnati', 1, 'class'],
#  [{' touch family': 1}, 1, ' touch family', 1, 'touch'],
#  [{' enought space': 1}, 1, ' enought space', 1, 'enought'],
#  [{' nice library music': 1}, 1, ' nice library music', 1, 'nice'],
#  [{'french carrier': 1}, 1, 'french carrier', 1, 'french'],
#  [{' water spot': 1}, 1, ' water spot', 1, 'water'],
#  [{' unlocked locked carrier spot screen': 1},
#   1,
#   ' unlocked locked carrier spot screen',
#   1,
#   'unlocked'],
#  [{' manufactured returned product': 1},
#   1,
#   ' manufactured returned product',
#   1,
#   'manufactured'],
#  [{' running io': 1}, 1, ' running io', 1, 'running'],
#  [{' ad item': 1}, 1, ' ad item', 1, 'ad'],
#  [{' item part': 1}, 1, ' item part', 1, 'item'],
#  [{' part adjustment amazon': 1}, 1, ' part adjustment amazon', 1, 'part'],
#  [{' expected due earlier order problem': 1},
#   1,
#   ' expected due earlier order problem',
#   1,
#   'expected'],
#  [{' big crack': 1}, 1, ' big crack', 1, 'big'],
#  [{' waiting answer': 1}, 1, ' waiting answer', 1, 'waiting'],
#  [{'useless drawer': 1}, 1, 'useless drawer', 1, 'useless'],
#  [{' fact phone': 1}, 1, ' fact phone', 1, 'fact'],
#  [{' locked pay': 1}, 1, ' locked pay', 1, 'locked'],
#  [{' no happy shopping seller': 1}, 1, ' no happy shopping seller', 1, 'no'],
#  [{' no dent phone look': 1}, 1, ' no dent phone look', 1, 'no'],
#  [{' unlocked baseband': 1}, 1, ' unlocked baseband', 1, 'unlocked'],
#  [{'ipod size': 1}, 1, 'ipod size', 1, 'ipod'],
#  [{' good support': 1}, 1, ' good support', 1, 'good'],
#  [{'old school shape': 1}, 1, 'old school shape', 1, 'old'],
#  [{'good incomplete condition': 1}, 1, 'good incomplete condition', 1, 'good'],
#  [{' miss accessory doubt': 1}, 1, ' miss accessory doubt', 1, 'miss'],
#  [{' additional spending': 1}, 1, ' additional spending', 1, 'additional'],
#  [{'missing switch cover': 1}, 1, 'missing switch cover', 1, 'missing'],
#  [{' cover thing': 1}, 1, ' cover thing', 1, 'cover'],
#  [{' look work': 1}, 1, ' look work', 1, 'look'],
#  [{' disappointed missing part': 1},
#   1,
#   ' disappointed missing part',
#   1,
#   'disappointed'],
#  [{' first great price item': 1}, 1, ' first great price item', 1, 'first'],
#  [{' internal part': 1}, 1, ' internal part', 1, 'internal'],
#  [{' braking front glass': 1}, 1, ' braking front glass', 1, 'braking'],
#  [{'fooled item description': 1}, 1, 'fooled item description', 1, 'fooled'],
#  [{' broken innocent buyer': 1}, 1, ' broken innocent buyer', 1, 'broken'],
#  [{' big issue': 1}, 1, ' big issue', 1, 'big'],
#  [{' issue batter': 1}, 1, ' issue batter', 1, 'issue'],
#  [{' life phone': 1}, 1, ' life phone', 1, 'life'],
#  [{' listened music': 1}, 1, ' listened music', 1, 'listened'],
#  [{' texting somehimes': 1}, 1, ' texting somehimes', 1, 'texting'],
#  [{' defeat purpose': 1}, 1, ' defeat purpose', 1, 'defeat'],
#  [{' cosmetic phone work': 1, ' cosmetic i d recomend': 1},
#   2,
#   ' cosmetic phone work',
#   2,
#   'cosmetic']]

# %%
df = pd.DataFrame(final_result,columns=["similar_words_and_count","count_of_similar_words","most_used_similar_word","total_similar_words", "associated_words"])

# %%
sorted_df = df.sort_values('total_similar_words',ascending=False).reset_index(drop=True)

# %%
sorted_df
# Out:
#                                similar_words_and_count  \
# 0    {'phone look': 1, ' agian phone': 1, ' phone v...
# 1    {' great condition phone': 1, 'phone perfect':...
# 2    {'great seller': 1, ' excellent price': 1, ' s...
# 3    {'apple product': 1, 'advertised apple iphone'...
# 4    {' old charger': 1, ' either charger': 1, ' ch...
# ..                                                 ...
# 566                            {' mine home apple': 1}
# 567                                  {' stand use': 1}
# 568                            {' iphone birthday': 1}
# 569                               {' n thing wife': 1}
# 570                                {' no good job': 1}
#
#      count_of_similar_words most_used_similar_word  total_similar_words  \
# 0                        44           phone screen                   35
# 1                        28     awesome phone mine                   25
# 2                        22     great seller brand                   21
# 3                        24            apple store                   18
# 4                        18            new charger                   12
# ..                      ...                    ...                  ...
# 566                       1        mine home apple                    1
# 567                       1              stand use                    1
# 568                       1        iphone birthday                    1
# 569                       1           n thing wife                    1
# 570                       1            no good job                    1
#
#     associated_words
# 0             wanted
# 1           thrilled
# 2                use
# 3              phone
# 4            plugged
# ..               ...
# 566             mine
# 567            stand
# 568           iphone
# 569                n
# 570               no
#
# [571 rows x 5 columns]

# %%
sorted_df.to_csv("/home/heptagon/Desktop/nps_review_analysis/dataset/amazon_mobile_review_associated_words.csv", index=False)

# %%
print((sorted_df.most_used_similar_word).to_list()[:20])
# Out:
# [' phone screen', 'awesome phone mine', ' great seller brand', ' apple store', ' new charger', 'good condition', 'great condition work', 'iphone manner phone work', ' paid return seller', 'purchasing experience', ' no scratch', ' sim card', ' new phone', ' download apps', ' telephone company', ' new speedy shipping', ' bad battery', ' great product', ' phone seller', ' deal price']

# %%
print((sorted_df.associated_words).to_list()[:20])
# Out:
# ['wanted', 'thrilled', 'use', 'phone', 'plugged', 'owned', 'new', 'verizon', 'returned', 'unlocked', 'terrible', 'verizon', 'update', 'system', 'telephone', 'super', 'worse', 'product', 'seller', 'plenty']

# %%
'''

['basic earbuds', 'sound quality', 'battery backup', 'basic product', 'no bass', 'product amazon',
'great price', 'noise cancellation', 'good quality', 'connectivity issue', 'decent decent sound experience',
'price point', 'bluetooth connectivity', 'awesome product rangebecause', 'low quality', 'affordable price',
'replacement issue', 'value money product', 'good deal', 'bulky size']

credit_union_of_new_jersey_detail_review
['credit union', 'great experience', 'loan process', 'great customer service', 'informative respectful
courteous efficient', 'person phone', 'staff work', 'account number', 'auto loan', 'best local bank',
'sure email', 'someone assistance', 'account change', 'prior appointment', 'bank guy', 'excellent amazing
attentive customer service', 'mortgage issue', 'helpful kind', 'person office', 'minute experience']

carousel_checks_detail_review
['new check', 'check order', 'carousel check', 'easy order', 'great price', 'customer service', 'great quality',
'fast delivery', 'bank address', 'orignial photo', 'great service', 'good price', 'correct information',
'check company', 'check photo', 'check cent', 'super fast delivery', 'duplicate check paper', 'time frame',
'repeat customer']

leaf_commercial_capital_inc_detail_review
['great job', 'leaf year', 'equipment business', 'simple loan', 'commercial financing', 'use leaf',
'loan representative', 'pleasure work', 'great company work', 'happy leaf', 'u equipment lease',
'funding department', 'u time', 'step way', 'easy quick business', 'leaf team', 'leaf time',
'usual eric amazing job', 'sure happy transaction', 'end lease']
    
nexo_detail_review
['crypto currency', 'current crypto environment', 'nexo support manager', 'nexo support', 'customer service',
 'quick useful customer service', 'nexo place', 'account use', 'support trust', 'best platform',
 'excellent customer service', 'easy use', 'nexo claim', 'best customer service', 'great experience nexo',
 'great support', 'external wallet', 'consideration experience', 'satisfied nexo point', 'service team']

By Current Algo
['basic earbuds', 'sound quality', 'battery backup', 'basic product', 'no bass', 'product amazon',
'great price', 'noise cancellation', 'good quality', 'connectivity issue', 'decent decent sound experience',
'price point', 'bluetooth connectivity', 'awesome product rangebecause', 'low quality', 'affordable price',
'replacement issue', 'value money product', 'good deal', 'bulky size']
 '''
# Out:
# "\n\n['basic earbuds', 'sound quality', 'battery backup', 'basic product', 'no bass', 'product amazon',\n'great price', 'noise cancellation', 'good quality', 'connectivity issue', 'decent decent sound experience',\n'price point', 'bluetooth connectivity', 'awesome product rangebecause', 'low quality', 'affordable price',\n'replacement issue', 'value money product', 'good deal', 'bulky size']\n\ncredit_union_of_new_jersey_detail_review\n['credit union', 'great experience', 'loan process', 'great customer service', 'informative respectful\ncourteous efficient', 'person phone', 'staff work', 'account number', 'auto loan', 'best local bank',\n'sure email', 'someone assistance', 'account change', 'prior appointment', 'bank guy', 'excellent amazing\nattentive customer service', 'mortgage issue', 'helpful kind', 'person office', 'minute experience']\n\ncarousel_checks_detail_review\n['new check', 'check order', 'carousel check', 'easy order', 'great price', 'customer service', 'great quality',\n'fast delivery', 'bank address', 'orignial photo', 'great service', 'good price', 'correct information',\n'check company', 'check photo', 'check cent', 'super fast delivery', 'duplicate check paper', 'time frame',\n'repeat customer']\n\nleaf_commercial_capital_inc_detail_review\n['great job', 'leaf year', 'equipment business', 'simple loan', 'commercial financing', 'use leaf',\n'loan representative', 'pleasure work', 'great company work', 'happy leaf', 'u equipment lease',\n'funding department', 'u time', 'step way', 'easy quick business', 'leaf team', 'leaf time',\n'usual eric amazing job', 'sure happy transaction', 'end lease']\n    \nnexo_detail_review\n['crypto currency', 'current crypto environment', 'nexo support manager', 'nexo support', 'customer service',\n 'quick useful customer service', 'nexo place', 'account use', 'support trust', 'best platform',\n 'excellent customer service', 'easy use', 'nexo claim', 'best customer service', 'great experience nexo',\n 'great support', 'external wallet', 'consideration experience', 'satisfied nexo point', 'service team']\n\nBy Current Algo\n['basic earbuds', 'sound quality', 'battery backup', 'basic product', 'no bass', 'product amazon',\n'great price', 'noise cancellation', 'good quality', 'connectivity issue', 'decent decent sound experience',\n'price point', 'bluetooth connectivity', 'awesome product rangebecause', 'low quality', 'affordable price',\n'replacement issue', 'value money product', 'good deal', 'bulky size']\n "

# %%
# Problem Statement : Now can you find out the keywords or expressions related to these keywords
#   Ex: Battery: Good, bad, slow charging etc, for wach keyword


    


#  https://www.analyticsvidhya.com/blog/2020/06/nlp-project-information-extraction/#h2_11

# two main task is in priority 1. keyword algo 2. associated words
# Plan : To Improve Main Keyword Algo and get associated words
# Try old algo (may get improved keywords) and few new ago also - Need 2 days to improve algo
# will try 2/3 algo to get associated words : also need 2/3 days

# we are getting list of keywords so
# 1. Implemanted : Currently taking 1st most word from the keywords
# 2. Working : To apply a specific Algo on entire datasets
# 3. Working : Also thinking the pattern matching, it will return entire sentence not a specific words. (as i noted on amazon website)
#     way : Extract sentense associated with keywords then apply the that method
